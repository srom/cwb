# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
from Bio import SeqIO
from rdkit import Chem
from rdkit.Chem import AllChem
from IPython.display import display

cwd = os.getcwd()
if cwd.endswith('notebook/PG'):
    os.chdir('../..')
    cwd = os.getcwd()

from src.pg_modelling.ligand_utils import generate_ccd_from_smiles, sanitize_ligand_name, generate_conformation

# %%
data_folder = Path(os.path.expanduser('~')) / 'Documents' / 'PG_modelling'
assert data_folder.is_dir()

# %% [markdown]
# ## Loading PG ligands

# %%
pg_df = pd.read_csv(data_folder / 'S_zooepidemicus' / 'S_zooepidemicus_PG_1mer.csv')
pg_subset = pg_df[
    pg_df['Name'].isin([
        '(NAG)(NAM)-AqKAA[3-NH2-AAA]',
        '(NAG)(NAM)-AqKAA[3-NH2-AA]',
        '(NAG)(NAM)-AqKAA[3-NH2-A]',
        '(NAG)(NAM)-AqKAA',
    ])
].reset_index(drop=True)
pg_subset['ligand_name'] = pg_subset['Name'].apply(lambda n: sanitize_ligand_name(n))
pg_subset = pg_subset.set_index('ligand_name')
print(f'Number of fragments in subset: {len(pg_subset):,}')
pg_subset.to_csv(data_folder / 'S_zooepidemicus' / 'S_zooepidemicus_PG_subset.csv')
pg_subset
# Out:
# Number of fragments in subset: 4
#                                                 Name  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  (NAG)(NAM)-AqKAA[3-NH2-AAA]
# NAG-NAM-AqKAA-3-NH2-AA    (NAG)(NAM)-AqKAA[3-NH2-AA]
# NAG-NAM-AqKAA-3-NH2-A      (NAG)(NAM)-AqKAA[3-NH2-A]
# NAG-NAM-AqKAA                       (NAG)(NAM)-AqKAA
#
#                                                                    Synonym  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...
# NAG-NAM-AqKAA-3-NH2-AA   GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...
# NAG-NAM-AqKAA-3-NH2-A    GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...
# NAG-NAM-AqKAA                      GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala
#
#                               Formula  Monoisotopic Mass Modifications  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  C48H82N12O22         1178.56666           NaN
# NAG-NAM-AqKAA-3-NH2-AA   C45H77N11O21         1107.52955           NaN
# NAG-NAM-AqKAA-3-NH2-A    C42H72N10O20         1036.49243           NaN
# NAG-NAM-AqKAA             C39H67N9O19          965.45532           NaN
#
#                          Degree Amidation  Degree Acetylation    Ontology  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA                 1                   2  G2--P5--S3
# NAG-NAM-AqKAA-3-NH2-AA                  1                   2  G2--P5--S2
# NAG-NAM-AqKAA-3-NH2-A                   1                   2  G2--P5--S1
# NAG-NAM-AqKAA                           1                   2      G2--P5
#
#                          PGN Units  Glycan Units  ...           Peptide  \
# ligand_name                                       ...
# NAG-NAM-AqKAA-3-NH2-AAA          1             2  ...  AqKAA[3-NH2-AAA]
# NAG-NAM-AqKAA-3-NH2-AA           1             2  ...   AqKAA[3-NH2-AA]
# NAG-NAM-AqKAA-3-NH2-A            1             2  ...    AqKAA[3-NH2-A]
# NAG-NAM-AqKAA                    1             2  ...             AqKAA
#
#                                                                     SMILES  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# NAG-NAM-AqKAA-3-NH2-AA   CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# NAG-NAM-AqKAA-3-NH2-A    CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# NAG-NAM-AqKAA            CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
#
#                                             INCHIKEY   clogP RT      [M+H]+  \
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  ZOSAGBPSZUYFTI-UHFFFAOYSA-N -9.2199  0  1179.57394
# NAG-NAM-AqKAA-3-NH2-AA   DSWIWDCFYFDFQG-UHFFFAOYSA-N -8.7246  0  1108.53683
# NAG-NAM-AqKAA-3-NH2-A    RFFQXYNMAAKXPS-UHFFFAOYSA-N -8.2293  0  1037.49971
# NAG-NAM-AqKAA            MYHLLWFYGIKMKM-UHFFFAOYSA-N -7.7340  0   966.46260
#
#                             [M+Na]+      [M+K]+   [M+2H]2+   [M+3H]3+
# ligand_name
# NAG-NAM-AqKAA-3-NH2-AAA  1201.55588  1217.52982  590.29061  393.86283
# NAG-NAM-AqKAA-3-NH2-AA   1130.51877  1146.49271  554.77206  370.18380
# NAG-NAM-AqKAA-3-NH2-A    1059.48165  1075.45559  519.25350  346.50476
# NAG-NAM-AqKAA             988.44454  1004.41848  483.73494  322.82572
#
# [4 rows x 25 columns]

# %%
ligand_folder = data_folder / 'S_zooepidemicus' / 'PG_ligands_pdb'
ligand_folder.mkdir(exist_ok=True)

for ligand_name, row in pg_subset.iterrows():
    raw_name = row['Name']
    smiles = row['SMILES']

    mol = Chem.MolFromSmiles(smiles)
    try:
        mol = generate_conformation(mol)
    except ValueError:
        print(f'Error for ligand: {raw_name}')
        raise

    output_path = ligand_folder / f'{ligand_name}.pdb'
    Chem.MolToPDBFile(mol, output_path.as_posix())
# Out:
# [16:14:23] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:23] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:23] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:24] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:24] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:24] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:24] Molecule does not have explicit Hs. Consider calling AddHs()
# [16:14:24] Molecule does not have explicit Hs. Consider calling AddHs()
