# %%
import os
from pathlib import Path

import pandas as pd

cwd = os.getcwd()
if cwd.endswith('notebook/PG'):
    os.chdir('../..')
    cwd = os.getcwd()

from src.pg_modelling.af3.scoring import process_af3_ligand_pulldown_results
from src.pg_modelling.protenix.scoring import process_protenix_ligand_pulldown_results

# %%
data_folder = Path(os.path.expanduser('~')) / 'Documents' / 'PG_modelling'
assert data_folder.is_dir()

protenix_trd_folder = data_folder / 'S_zooepidemicus' / 'protenix__TRD_pulldown'
assert protenix_trd_folder.is_dir()

protenix_trd_2mer_folder = data_folder / 'S_zooepidemicus' / 'protenix__TRD_pulldown_2mer'
assert protenix_trd_2mer_folder.is_dir()

# %%
pg_subset = pd.read_csv(data_folder / 'S_zooepidemicus' / 'S_zooepidemicus_pg_subset.csv')
print(f'Number of fragments: {len(pg_subset):,}')
pg_subset.head()
# Out:
# Number of fragments: 4
#                ligand_name                         Name  \
# 0  NAG-NAM-AqKAA-3-NH2-AAA  (NAG)(NAM)-AqKAA[3-NH2-AAA]
# 1   NAG-NAM-AqKAA-3-NH2-AA   (NAG)(NAM)-AqKAA[3-NH2-AA]
# 2    NAG-NAM-AqKAA-3-NH2-A    (NAG)(NAM)-AqKAA[3-NH2-A]
# 3            NAG-NAM-AqKAA             (NAG)(NAM)-AqKAA
#
#                                              Synonym       Formula  \
# 0  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C48H82N12O22
# 1  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C45H77N11O21
# 2  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C42H72N10O20
# 3            GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala   C39H67N9O19
#
#    Monoisotopic Mass  Modifications  Degree Amidation  Degree Acetylation  \
# 0         1178.56666            NaN                 1                   2
# 1         1107.52955            NaN                 1                   2
# 2         1036.49243            NaN                 1                   2
# 3          965.45532            NaN                 1                   2
#
#      Ontology  PGN Units  ...           Peptide  \
# 0  G2--P5--S3          1  ...  AqKAA[3-NH2-AAA]
# 1  G2--P5--S2          1  ...   AqKAA[3-NH2-AA]
# 2  G2--P5--S1          1  ...    AqKAA[3-NH2-A]
# 3      G2--P5          1  ...             AqKAA
#
#                                               SMILES  \
# 0  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 1  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 2  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 3  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
#
#                       INCHIKEY   clogP  RT      [M+H]+     [M+Na]+  \
# 0  ZOSAGBPSZUYFTI-UHFFFAOYSA-N -9.2199   0  1179.57394  1201.55588
# 1  DSWIWDCFYFDFQG-UHFFFAOYSA-N -8.7246   0  1108.53683  1130.51877
# 2  RFFQXYNMAAKXPS-UHFFFAOYSA-N -8.2293   0  1037.49971  1059.48165
# 3  MYHLLWFYGIKMKM-UHFFFAOYSA-N -7.7340   0   966.46260   988.44454
#
#        [M+K]+   [M+2H]2+   [M+3H]3+
# 0  1217.52982  590.29061  393.86283
# 1  1146.49271  554.77206  370.18380
# 2  1075.45559  519.25350  346.50476
# 3  1004.41848  483.73494  322.82572
#
# [4 rows x 26 columns]

# %%
protenix_results_df = process_protenix_ligand_pulldown_results(
    'ZoocinA_TRD',
    protenix_trd_folder,
    run_posebusters=True,
    score_all_sample=True,
)
protenix_results_df
# Out:
#                                                                          structure_file  \
# protein_name ligand_name
# ZoocinA_TRD  NAG-NAM-AqKAA-3-NH2-A    /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              NAG-NAM-AqKAA            /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              NAG-NAM-AqKAA-3-NH2-AA   /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              NAG-NAM-AqKAA-3-NH2-AAA  /Users/rs1521/Documents/PG_modelling/S_zooepid...
#
#                                            ptm      iptm  confidence  \
# protein_name ligand_name
# ZoocinA_TRD  NAG-NAM-AqKAA-3-NH2-A    0.970008  0.948317       0.953
#              NAG-NAM-AqKAA            0.951062  0.899271       0.910
#              NAG-NAM-AqKAA-3-NH2-AA   0.964833  0.936061       0.942
#              NAG-NAM-AqKAA-3-NH2-AAA  0.946256  0.895658       0.906
#
#                                       posebusters_score posebusters_errors  \
# protein_name ligand_name
# ZoocinA_TRD  NAG-NAM-AqKAA-3-NH2-A                   20               None
#              NAG-NAM-AqKAA                           20               None
#              NAG-NAM-AqKAA-3-NH2-AA                  20               None
#              NAG-NAM-AqKAA-3-NH2-AAA                 20               None
#
#                                       energy_ratio
# protein_name ligand_name
# ZoocinA_TRD  NAG-NAM-AqKAA-3-NH2-A             9.2
#              NAG-NAM-AqKAA                     9.3
#              NAG-NAM-AqKAA-3-NH2-AA            9.4
#              NAG-NAM-AqKAA-3-NH2-AAA          14.1

# %%
protenix_results_df.loc[('ZoocinA_TRD', 'NAG-NAM-AqKAA-3-NH2-AA'), 'structure_file']
# Out:
# '/Users/rs1521/Documents/PG_modelling/S_zooepidemicus/protenix__TRD_pulldown/ZoocinA_TRD_O54308_179_283__NAG-NAM-AqKAA-3-NH2-AA/seed_49/predictions/ZoocinA_TRD_O54308_179_283__NAG-NAM-AqKAA-3-NH2-AA_seed_49_sample_1.cif'

# %%
protenix_results_df.loc[('ZoocinA_TRD', 'NAG-NAM-AqKAA-3-NH2-AAA'), 'structure_file']
# Out:
# '/Users/rs1521/Documents/PG_modelling/S_zooepidemicus/protenix__TRD_pulldown/ZoocinA_TRD_O54308_179_283__NAG-NAM-AqKAA-3-NH2-AAA/seed_822/predictions/ZoocinA_TRD_O54308_179_283__NAG-NAM-AqKAA-3-NH2-AAA_seed_822_sample_3.cif'

# %%
import subprocess
import tempfile

with tempfile.TemporaryDirectory() as tmpdir:
    pdb_path = Path(tmpdir) / 'structure.pdb'
    cif_path = protenix_results_df.loc[('ZoocinA_TRD', 'NAG-NAM-AqKAA-3-NH2-AA'), 'structure_file']

    subprocess.run(['obabel', '-icif', cif_path, '-opdb', '-O', pdb_path.as_posix()])

    subprocess.run(['plip', '-f', pdb_path.as_posix(), '-o', tmpdir, '-t'])

    with (Path(tmpdir) / 'report.txt').open() as f:
        content = f.read()
        print(content)
# Out:
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is ZoocinA_TRD_O54308_179_283__NAG-NAM-AqKAA-3-NH2-AA_seed_49_sample_1_predicted_by_protenix)
#
# 1 molecule converted
# None
# 2025-02-06 16:02:28,567 [INFO] [plipcmd.py:134] plip.plipcmd: Protein-Ligand Interaction Profiler (PLIP) 2.4.0
# 2025-02-06 16:02:28,567 [INFO] [plipcmd.py:135] plip.plipcmd: brought to you by: PharmAI GmbH (2020-2021) - www.pharm.ai - hello@pharm.ai
# 2025-02-06 16:02:28,567 [INFO] [plipcmd.py:136] plip.plipcmd: please cite: Adasme,M. et al. PLIP 2021: expanding the scope of the protein-ligand interaction profiler to DNA and RNA. Nucl. Acids Res. (05 May 2021), gkab294. doi: 10.1093/nar/gkab294
# 2025-02-06 16:02:28,567 [INFO] [plipcmd.py:60] plip.plipcmd: starting analysis of structure.pdb
# 2025-02-06 16:02:28,737 [INFO] [plipcmd.py:175] plip.plipcmd: finished analysis, find the result files in /var/folders/xd/714yy8tn5vz90_wtnn7vglhc0000gq/T/tmpqxpbf19v/
# Prediction of noncovalent interactions for PDB structure STRUCTURE_PROTEIN
# ==========================================================================
# Created on 2025/02/06 using PLIP v2.4.0
#
# If you are using PLIP in your work, please cite:
# Adasme,M. et al. PLIP 2021: expanding the scope of the protein-ligand interaction profiler to DNA and RNA. Nucl. Acids Res. (05 May 2021), gkab294. doi: 10.1093/nar/gkab294
# Analysis was done on model 1.
#
# l01:B:1 (l01) - SMALLMOLECULE
# -----------------------------
# Interacting chain(s): A
#
#
# **Hydrophobic Interactions**
# +-------+---------+----------+-----------+-------------+--------------+------+--------------+---------------+----------------------+----------------------+
# | RESNR | RESTYPE | RESCHAIN | RESNR_LIG | RESTYPE_LIG | RESCHAIN_LIG | DIST | LIGCARBONIDX | PROTCARBONIDX | LIGCOO               | PROTCOO              |
# +=======+=========+==========+===========+=============+==============+======+==============+===============+======================+======================+
# | 30    | VAL     | A        | 1         | l01         | B            | 3.09 | 873          | 256           | 9.637, 3.718, 13.527 | 9.058, 1.480, 11.483 |
# +-------+---------+----------+-----------+-------------+--------------+------+--------------+---------------+----------------------+----------------------+
# | 82    | TRP     | A        | 1         | l01         | B            | 3.61 | 862          | 626           | 6.400, 12.619, 5.797 | 4.128, 12.777, 2.999 |
# +-------+---------+----------+-----------+-------------+--------------+------+--------------+---------------+----------------------+----------------------+
# | 82    | TRP     | A        | 1         | l01         | B            | 3.57 | 867          | 634           | 9.042, 8.924, 3.482  | 6.438, 9.809, 1.203  |
# +-------+---------+----------+-----------+-------------+--------------+------+--------------+---------------+----------------------+----------------------+
#
#
# **Hydrogen Bonds**
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | RESNR | RESTYPE | RESCHAIN | RESNR_LIG | RESTYPE_LIG | RESCHAIN_LIG | SIDECHAIN | DIST_H-A | DIST_D-A | DON_ANGLE | PROTISDON | DONORIDX | DONORTYPE | ACCEPTORIDX | ACCEPTORTYPE | LIGCOO                 | PROTCOO                |
# +=======+=========+==========+===========+=============+==============+===========+==========+==========+===========+===========+==========+===========+=============+==============+========================+========================+
# | 12    | ASN     | A        | 1         | l01         | B            | True      | 2.80     | 3.71     | 153.34    | True      | 103      | Nam       | 834         | O2           | 5.532, -4.688, 11.544  | 9.027, -4.167, 12.661  |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 16    | GLN     | A        | 1         | l01         | B            | True      | 3.22     | 3.71     | 112.01    | True      | 138      | Nam       | 834         | O2           | 5.532, -4.688, 11.544  | 5.884, -3.968, 7.924   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 26    | ASP     | A        | 1         | l01         | B            | False     | 1.99     | 2.90     | 147.58    | False     | 868      | N3        | 213         | O2           | 9.880, 7.800, 5.462    | 11.623, 7.398, 3.178   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 31    | ASP     | A        | 1         | l01         | B            | True      | 2.70     | 3.29     | 119.26    | False     | 852      | Nam       | 263         | O3           | 5.672, 6.183, 12.194   | 8.252, 5.127, 10.443   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 31    | ASP     | A        | 1         | l01         | B            | True      | 1.79     | 2.76     | 169.88    | False     | 871      | Nam       | 263         | O3           | 8.407, 5.738, 13.132   | 8.252, 5.127, 10.443   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 31    | ASP     | A        | 1         | l01         | B            | True      | 2.92     | 3.84     | 156.11    | False     | 876      | Nam       | 263         | O3           | 10.859, 6.637, 12.827  | 8.252, 5.127, 10.443   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 32    | ASN     | A        | 1         | l01         | B            | True      | 2.11     | 3.06     | 161.63    | True      | 272      | Nam       | 865         | O2           | 7.338, 8.654, 5.994    | 6.201, 6.286, 4.429    |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 77    | SER     | A        | 1         | l01         | B            | True      | 2.91     | 3.83     | 155.49    | False     | 863      | Nam       | 598         | O3           | 7.984, 10.816, 5.946   | 10.374, 13.015, 3.925  |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 89    | THR     | A        | 1         | l01         | B            | False     | 2.61     | 3.39     | 137.75    | False     | 888      | O3        | 685         | O2           | -1.809, -3.909, 14.000 | -1.815, -5.016, 10.797 |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 92    | ASN     | A        | 1         | l01         | B            | False     | 2.97     | 3.79     | 141.28    | True      | 697      | Nam       | 845         | O2           | 1.516, 2.761, 14.115   | -0.772, 2.016, 11.184  |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 92    | ASN     | A        | 1         | l01         | B            | True      | 2.79     | 3.67     | 148.80    | True      | 704      | Nam       | 845         | O2           | 1.516, 2.761, 14.115   | -1.698, 4.487, 13.717  |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 92    | ASN     | A        | 1         | l01         | B            | False     | 1.95     | 2.79     | 141.80    | False     | 883      | Nam       | 700         | O2           | 4.234, 1.506, 10.034   | 1.806, 2.886, 10.143   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+
# | 94    | TRP     | A        | 1         | l01         | B            | True      | 2.88     | 3.64     | 134.73    | False     | 858      | Nam       | 720         | N2           | 6.086, 11.247, 8.967   | 3.710, 8.699, 10.010   |
# +-------+---------+----------+-----------+-------------+--------------+-----------+----------+----------+-----------+-----------+----------+-----------+-------------+--------------+------------------------+------------------------+

# %% [markdown]
# ## 2mer

# %%
protenix_results_2mer_df = process_protenix_ligand_pulldown_results(
    'ZoocinA_TRD',
    protenix_trd_2mer_folder,
    run_posebusters=True,
    score_all_sample=True,
)
protenix_results_2mer_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 protenix_results_df = process_protenix_ligand_pulldown_results(
#       2     'ZoocinA_TRD',
#       3     protenix_trd_2mer_folder,
#       4     run_posebusters=True,
#       5     score_all_sample=True,
#       6 )
#       7 protenix_results_df
#
# File ~/workspace/cwb/src/pg_modelling/protenix/scoring.py:72, in process_protenix_ligand_pulldown_results(protein_name, results_folder, run_posebusters, score_all_sample)
#      70 scores, errors, energy_ratios = [], [], []
#      71 for structure_file_path in protenix_results_df['structure_file'].values:
# ---> 72     score, errs, energy_ratio = run_protenix_posebusters(structure_file_path)
#      73     scores.append(score)
#      74     errors.append(errs)
#
# File ~/workspace/cwb/src/pg_modelling/protenix/scoring.py:96, in run_protenix_posebusters(structure_path_str, ligand_id)
#      95 def run_protenix_posebusters(structure_path_str : str, ligand_id='l01'):
# ---> 96     pose_busters_res = run_pose_busters(
#      97         Path(structure_path_str),
#      98         ligand_id=ligand_id,
#      99         full_report=True,
#     100     ).iloc[0]
#     102     pose_busters_score = pose_busters_res['score']
#     103     energy_ratio = pose_busters_res['energy_ratio']
#
# File ~/workspace/cwb/src/pg_modelling/ligand_utils.py:217, in run_pose_busters(input_mmcif, ligand_id, full_report)
#     214     extract_protein_and_ligand_from_mmcif(input_mmcif, protein_pdb_path, ligand_sdf_path, ligand_id)
#     216     buster = PoseBusters(config="dock")
# --> 217     res_df = buster.bust(
#     218         mol_pred=ligand_sdf_path,
#     219         mol_cond=protein_pdb_path,
#     220         mol_true=None,
#     221         full_report=full_report,
#     222     )
#     224 boolean_columns = POSEBUSTERS_CHECKS
#     225 res_df['ligand_id'] = ligand_id
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/posebusters.py:111, in PoseBusters.bust(self, mol_pred, mol_true, mol_cond, full_report)
#     107 self.file_paths = pd.DataFrame([[mol_pred, mol_true, mol_cond] for mol_pred in mol_pred_list], columns=columns)
#     109 results_gen = self._run()
# --> 111 df = pd.concat([_dataframe_from_output(d, self.config, full_report=full_report) for d in results_gen])
#     112 df.index.names = ["file", "molecule"]
#     113 df.columns = [c.lower().replace(" ", "_") for c in df.columns]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/posebusters.py:111, in <listcomp>(.0)
#     107 self.file_paths = pd.DataFrame([[mol_pred, mol_true, mol_cond] for mol_pred in mol_pred_list], columns=columns)
#     109 results_gen = self._run()
# --> 111 df = pd.concat([_dataframe_from_output(d, self.config, full_report=full_report) for d in results_gen])
#     112 df.index.names = ["file", "molecule"]
#     113 df.columns = [c.lower().replace(" ", "_") for c in df.columns]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/posebusters.py:173, in PoseBusters._run(self)
#     171     module_output: dict[str, Any] = {"results": {}}
#     172 else:
# --> 173     module_output = func(**args_needed)
#     175 # save to object
#     176 self.results[results_key].extend([(name, k, v) for k, v in module_output["results"].items()])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/modules/energy_ratio.py:81, in check_energy_ratio(mol_pred, threshold_energy_ratio, ensemble_number_conformations, inchi_strict)
#      78     conf_energy = np.nan
#      80 try:
# ---> 81     avg_energy = float(get_average_energy(inchi, ensemble_number_conformations))
#      82 except Exception as e:
#      83     logger.warning(_warning_prefix + "failed to calculate ensemble conformation energy for %s: %s", inchi, e)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/modules/energy_ratio.py:107, in get_average_energy(inchi, n_confs, num_threads)
#     105 with CaptureLogger():
#     106     mol = MolFromInchi(inchi)
# --> 107 energies = new_conformation(mol, n_confs, num_threads)["energies"]
#     108 return sum(energies) / len(energies)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/posebusters/modules/energy_ratio.py:129, in new_conformation(mol, n_confs, num_threads, energy_minimization)
#     127 # etkdg
#     128 with CaptureLogger():
# --> 129     cids_etkdg = EmbedMultipleConfs(mol_etkdg, n_confs, etkdg)
#     130     assert len(cids_etkdg) == n_confs, "Failed to generate conformations."
#     132 # energy minimization
#
# KeyboardInterrupt:

# %% [markdown]
# ## AF3 results

# %%
pg_def = pd.concat(
    [
        pd.read_csv(data_folder / 'S_zooepidemicus' / 'S_zooepidemicus_pg_subset.csv'),
        pd.read_csv(data_folder / 'S_zooepidemicus' / 'S_zooepidemicus_PG_subset_2mer.csv'),
    ],
    ignore_index=True,
)
pg_def
# Out:
#                           ligand_name  \
# 0             NAG-NAM-AqKAA-3-NH2-AAA
# 1              NAG-NAM-AqKAA-3-NH2-AA
# 2               NAG-NAM-AqKAA-3-NH2-A
# 3                       NAG-NAM-AqKAA
# 4    NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA
# 5   NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA
# 6  NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA
#
#                                             Name  \
# 0                    (NAG)(NAM)-AqKAA[3-NH2-AAA]
# 1                     (NAG)(NAM)-AqKAA[3-NH2-AA]
# 2                      (NAG)(NAM)-AqKAA[3-NH2-A]
# 3                               (NAG)(NAM)-AqKAA
# 4    (NAG)(NAM)-AqKAA[3-NH2-A];(3br-4)-None-AqKA
# 5   (NAG)(NAM)-AqKAA[3-NH2-AA];(3br-4)-None-AqKA
# 6  (NAG)(NAM)-AqKAA[3-NH2-AAA];(3br-4)-None-AqKA
#
#                                              Synonym        Formula  \
# 0  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...   C48H82N12O22
# 1  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...   C45H77N11O21
# 2  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...   C42H72N10O20
# 3            GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala    C39H67N9O19
# 4  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C59H102N16O25
# 5  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C62H107N17O26
# 6  GlcNAc.MurNAc--Ala.γ-isoGln.Lys.Ala.Ala[3--NH2...  C65H112N18O27
#
#    Monoisotopic Mass Modifications  Degree Amidation  Degree Acetylation  \
# 0         1178.56666           NaN                 1                   2
# 1         1107.52955           NaN                 1                   2
# 2         1036.49243           NaN                 1                   2
# 3          965.45532           NaN                 1                   2
# 4         1434.72020       Amidase                 2                   2
# 5         1505.75732       Amidase                 2                   2
# 6         1576.79443       Amidase                 2                   2
#
#          Ontology  PGN Units  ...           Peptide  \
# 0      G2--P5--S3          1  ...  AqKAA[3-NH2-AAA]
# 1      G2--P5--S2          1  ...   AqKAA[3-NH2-AA]
# 2      G2--P5--S1          1  ...    AqKAA[3-NH2-A]
# 3          G2--P5          1  ...             AqKAA
# 4  G2--P5--S1--P4          2  ...    AqKAA[3-NH2-A]
# 5  G2--P5--S2--P4          2  ...   AqKAA[3-NH2-AA]
# 6  G2--P5--S3--P4          2  ...  AqKAA[3-NH2-AAA]
#
#                                               SMILES  \
# 0  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 1  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 2  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 3  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 4  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 5  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
# 6  CC(=O)NC1C(OC2C(CO)OC(O)C(NC(C)=O)C2OC(C)C(=O)...
#
#                       INCHIKEY    clogP RT      [M+H]+     [M+Na]+  \
# 0  ZOSAGBPSZUYFTI-UHFFFAOYSA-N  -9.2199  0  1179.57394  1201.55588
# 1  DSWIWDCFYFDFQG-UHFFFAOYSA-N  -8.7246  0  1108.53683  1130.51877
# 2  RFFQXYNMAAKXPS-UHFFFAOYSA-N  -8.2293  0  1037.49971  1059.48165
# 3  MYHLLWFYGIKMKM-UHFFFAOYSA-N  -7.7340  0   966.46260   988.44454
# 4  BZVVPZAQDNTOKX-UHFFFAOYSA-N -10.8558  0  1435.72748  1457.70942
# 5  DDZFHCPFDIFHGE-UHFFFAOYSA-N -11.3511  0  1506.76460  1528.74654
# 6  WCDFAYHLLBVZND-UHFFFAOYSA-N -11.8464  0  1577.80171  1599.78365
#
#        [M+K]+   [M+2H]2+   [M+3H]3+
# 0  1217.52982  590.29061  393.86283
# 1  1146.49271  554.77206  370.18380
# 2  1075.45559  519.25350  346.50476
# 3  1004.41848  483.73494  322.82572
# 4  1473.68336  718.36738  479.24735
# 5  1544.72048  753.88594  502.92639
# 6  1615.75759  789.40450  526.60542
#
# [7 rows x 26 columns]

# %%
main_results_df = process_af3_ligand_pulldown_results(
    'ZoocinA_TRD',
    data_folder / 'S_zooepidemicus' / 'af3__TRD_pulldown',
    run_posebusters=True,
)
main_results_df
# Out:
#                                                                                                    folder  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA                               zoocina_trd_o54308_179_283__nag-nam-aqkaa
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh2-a
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#
#                                                                                            structure_file  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA                       /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             /Users/rs1521/Documents/PG_modelling/S_zooepid...
#
#                                                          ptm  iptm  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    0.83  0.77
#              LIG-PG-NAG-NAM-AqKAA                       0.84  0.75
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               0.83  0.70
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  0.78  0.64
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   0.76  0.60
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              0.89  0.83
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             0.76  0.56
#
#                                                         confidence  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA         0.782
#              LIG-PG-NAG-NAM-AqKAA                            0.768
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                    0.726
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA       0.668
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA        0.632
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA                   0.842
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA                  0.600
#
#                                                         posebusters_score  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA                   20
#              LIG-PG-NAG-NAM-AqKAA                                      20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                              20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA                 20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA                  20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA                             19
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA                            19
#
#                                                                  posebusters_errors
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA                           None
#              LIG-PG-NAG-NAM-AqKAA                                              None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                                      None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA                         None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA                          None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              minimum_distance_to_protein
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             minimum_distance_to_protein

# %%
results_df = process_af3_ligand_pulldown_results(
    'ZoocinA_TRD',
    data_folder / 'S_zooepidemicus' / 'af3__TRD_pulldown',
    run_posebusters=True,
    score_all_sample=True,
)
results_df
# Out:
#                                                                                                    folder  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA                               zoocina_trd_o54308_179_283__nag-nam-aqkaa
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh2-a
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh...
#
#                                                                                            structure_file  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA                       /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   /Users/rs1521/Documents/PG_modelling/S_zooepid...
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             /Users/rs1521/Documents/PG_modelling/S_zooepid...
#
#                                                          ptm  iptm  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA              0.88  0.83
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA    0.83  0.77
#              LIG-PG-NAG-NAM-AqKAA                       0.84  0.75
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A               0.83  0.70
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA  0.78  0.64
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA   0.76  0.60
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA             0.74  0.56
#
#                                                         confidence  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA                   0.840
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA         0.782
#              LIG-PG-NAG-NAM-AqKAA                            0.768
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                    0.726
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA       0.668
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA        0.632
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA                  0.596
#
#                                                         posebusters_score  \
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA                             20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA                   20
#              LIG-PG-NAG-NAM-AqKAA                                      20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                              20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA                 20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA                  20
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA                            20
#
#                                                        posebusters_errors
# protein_name ligand_name
# ZoocinA_TRD  LIG-PG-NAG-NAM-AqKAA-3-NH2-AA                           None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A-3br-4-AqKA                 None
#              LIG-PG-NAG-NAM-AqKAA                                    None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-A                            None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA-3br-4-AqKA               None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AA-3br-4-AqKA                None
#              LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA                          None

# %%
results_df.loc[('ZoocinA_TRD', 'LIG-PG-NAG-NAM-AqKAA-3-NH2-AA'), 'structure_file']
# Out:
# '/Users/rs1521/Documents/PG_modelling/S_zooepidemicus/af3__TRD_pulldown/zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh2-aa/seed-29_sample-1/model.cif'

# %%
results_df.loc[('ZoocinA_TRD', 'LIG-PG-NAG-NAM-AqKAA-3-NH2-AAA'), 'structure_file']
# Out:
# '/Users/rs1521/Documents/PG_modelling/S_zooepidemicus/af3__TRD_pulldown/zoocina_trd_o54308_179_283__nag-nam-aqkaa-3-nh2-aaa/seed-98_sample-3/model.cif'
