# %% [markdown]
# # Differential presence of CWB domains at genus level
#
# Check for the presence of cell wall binding domains (CWB) in monoderm genera.
#
# In particular, we are interested in cases where most species, but not all, encode a specific CWB domain.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

cwd = os.getcwd()
if cwd.endswith('notebook'):
    os.chdir('..')
    cwd = os.getcwd()

# %%
sns.set_theme(palette='colorblind', font_scale=1.3)
palette = sns.color_palette().as_hex()

data_folder = Path('./data/')
assert data_folder.is_dir()

db_proka = Path('../db_proka/')
assert db_proka.is_dir()

# %% [markdown]
# ## Load GTDB metadata file

# %%
gtdb_metadata = pd.read_csv(db_proka / 'gtdb_metadata.csv')
gtdb_metadata['domain'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[0].replace('d__', ''))
gtdb_metadata['gtdb_phylum'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[1].replace('p__', ''))
gtdb_metadata['gtdb_class'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[2].replace('c__', ''))
gtdb_metadata['gtdb_order'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[3].replace('o__', ''))
gtdb_metadata['gtdb_family'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[4].replace('f__', ''))
gtdb_metadata['gtdb_genus'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[5].replace('g__', ''))
gtdb_metadata['gtdb_species'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[6].replace('s__', ''))
gtdb_metadata = gtdb_metadata.set_index('ncbi_accession', drop=True)

# %% [markdown]
# ## Focus on Bacillota (Firmicutes) & Actinomycetota

# %%
phylum_seeds = ['Bacillota', 'Actinomycetota']
monoderm_phyla = sorted([
    p for p in gtdb_metadata['gtdb_phylum'].unique()
    if any([s in p for s in phylum_seeds])
])

# Monoderms with complete genomes:
monoderms_cg = gtdb_metadata[
    (gtdb_metadata['gtdb_phylum'].isin(monoderm_phyla)) &
    (
        (gtdb_metadata['ncbi_assembly_level']  == 'Complete Genome') |
        (gtdb_metadata['checkm_completeness'] > 98)
    )
]

print(f'Number of species: {len(monoderms_cg):,}')
print(f'Number of genera : {len(monoderms_cg["gtdb_genus"].unique()):,}')
# Out:
# Number of species: 5,475
# Number of genera : 1,932

# %%
n_species_per_genus = monoderms_cg.reset_index()[
    ['gtdb_genus', 'ncbi_accession']
].groupby('gtdb_genus').nunique().sort_values(['ncbi_accession'], ascending=False)

# %%
candidate_genera = sorted(n_species_per_genus[n_species_per_genus['ncbi_accession'] == 10].index.tolist())

print(f'Number of genera with 10 complete genomes or more: {len(candidate_genera)}')

candidate_genera
# Out:
# Number of genera with 10 complete genomes or more: 106
# ['Actinokineospora',
#  'Actinoplanes',
#  'Actinosynnema',
#  'Aerococcus',
#  'Aeromicrobium',
#  'Agrococcus',
#  'Alicyclobacillus',
#  'Amycolatopsis',
#  'Anaerobacillus_A',
#  'Arthrobacter_D',
#  'Bacillus',
#  'Bacillus_A',
#  'Blautia_A',
#  'Brevibacillus',
#  'Carnobacterium_A',
#  'Cellulomonas',
#  'Cellulosimicrobium',
#  'Choladocola',
#  'Clostridium',
#  'Clostridium_AD',
#  'Clostridium_B',
#  'Corynebacterium',
#  'Cryobacterium',
#  'DTU059',
#  'Domibacillus',
#  'Enterocloster',
#  'Enterococcus',
#  'Enterococcus_A',
#  'Enterococcus_B',
#  'Exiguobacterium',
#  'Exiguobacterium_A',
#  'Faecalibacterium',
#  'Fictibacillus',
#  'Frigoribacterium',
#  'Galliscardovia',
#  'Geodermatophilus',
#  'Glutamicibacter',
#  'Glycomyces',
#  'Gordonia',
#  'Gottfriedia',
#  'Gracilibacillus',
#  'Halanaerobium',
#  'Halobacillus',
#  'Halobacillus_A',
#  'Herbiconiux',
#  'Isoptericola',
#  'Jeotgalibacillus',
#  'Kocuria',
#  'Kribbella',
#  'Lactiplantibacillus',
#  'Lactobacillus',
#  'Leifsonia',
#  'Lentibacillus',
#  'Lentilactobacillus',
#  'Lentzea',
#  'Leucobacter',
#  'Levilactobacillus',
#  'Ligilactobacillus',
#  'Limosilactobacillus',
#  'Lysinibacillus',
#  'Mesomycoplasma',
#  'Microbacterium',
#  'Microbispora',
#  'Micromonospora',
#  'Mobilitalea',
#  'Mycobacterium',
#  'Mycoplasmoides',
#  'Neobacillus',
#  'Nocardia',
#  'Nocardiopsis',
#  'Nonomuraea',
#  'Paenibacillus',
#  'Paenibacillus_B',
#  'Paenibacillus_E',
#  'Paenibacillus_S',
#  'Paenibacillus_Z',
#  'Paeniglutamicibacter',
#  'Paucisalibacillus',
#  'Pediococcus',
#  'Pedococcus',
#  'Peptoniphilus_A',
#  'Peptostreptococcus',
#  'Peribacillus',
#  'Planococcus',
#  'Pseudonocardia',
#  'Psychrobacillus',
#  'Rossellomorea',
#  'Rothia',
#  'Saccharibacillus',
#  'Saccharopolyspora',
#  'Serinicoccus',
#  'Sinomonas',
#  'Specibacter',
#  'Spirillospora',
#  'Spiroplasma_A',
#  'Sporosarcina',
#  'Staphylococcus',
#  'Streptacidiphilus',
#  'Streptococcus',
#  'Streptomyces',
#  'Streptosporangium',
#  'Sutcliffiella_A',
#  'Tsukamurella',
#  'Ureibacillus',
#  'Vagococcus',
#  'Virgibacillus']

# %% [markdown]
# ## Cell wall binding domains landscape

# %%
cwb_domains = [
    'PG_binding_1',
    'PG_binding_2',
    'PG_binding_3',
    'AMIN',
    'SPOR',
    'SH3_1',
    'SH3_2',
    'SH3_3',
    'SH3_4',
    'SH3_5',
    'SH3_6',
    'SH3_7',
    'SH3_9',
    'SH3_16',
    'LysM',
    'Choline_bind_1',
    'Choline_bind_2',
    'Choline_bind_3',
    'CW_binding_2',
    'CW_7',
    'PSA_CBD',
    'ZoocinA_TRD',
    'GW',
    'OapA',
]

# %%
## Loading Pfam summary, a large table, which may take a while (but should take less than 5 minutes).

cwb_summary = pd.read_csv(
    db_proka / 'Pfam-A_summary.tsv.gz', 
    sep='\t', 
    index_col='assembly_accession',
).drop(columns=['asm_name'])[cwb_domains]

# %%
taxonomy_columns = [
    'domain',
    'gtdb_phylum',
    'gtdb_class',
    'gtdb_order',
    'gtdb_family',
    'gtdb_genus',
    'gtdb_species',
]

dfs = []
for genus in candidate_genera:
    accessions = monoderms_cg[monoderms_cg['gtdb_genus'] == genus].index.tolist()

    df = cwb_summary.loc[accessions]

    for cwb_col in cwb_domains:
        df[cwb_col] = (df[cwb_col] > 0).astype(int)

    cols = df.columns.tolist()

    for tax_col in taxonomy_columns:
        df[tax_col] = [monoderms_cg.loc[accession, tax_col] for accession in df.index]

    dfs.append(
        df[taxonomy_columns + cols].reset_index()
    )

cwb_df = pd.concat(dfs, ignore_index=True).set_index('assembly_accession', drop=True)
cwb_df.head()
# Out:
#                       domain     gtdb_phylum     gtdb_class       gtdb_order  \
# assembly_accession
# GCF_000564855.1     Bacteria  Actinomycetota  Actinomycetia  Mycobacteriales
# GCF_001940455.1     Bacteria  Actinomycetota  Actinomycetia  Mycobacteriales
# GCF_002934265.1     Bacteria  Actinomycetota  Actinomycetia  Mycobacteriales
# GCF_004362515.1     Bacteria  Actinomycetota  Actinomycetia  Mycobacteriales
# GCF_014323725.1     Bacteria  Actinomycetota  Actinomycetia  Mycobacteriales
#
#                            gtdb_family        gtdb_genus  \
# assembly_accession
# GCF_000564855.1     Pseudonocardiaceae  Actinokineospora
# GCF_001940455.1     Pseudonocardiaceae  Actinokineospora
# GCF_002934265.1     Pseudonocardiaceae  Actinokineospora
# GCF_004362515.1     Pseudonocardiaceae  Actinokineospora
# GCF_014323725.1     Pseudonocardiaceae  Actinokineospora
#
#                                         gtdb_species  PG_binding_1  \
# assembly_accession
# GCF_000564855.1     Actinokineospora spheciospongiae             1
# GCF_001940455.1        Actinokineospora bangkokensis             1
# GCF_002934265.1        Actinokineospora auranticolor             1
# GCF_004362515.1                Actinokineospora alba             1
# GCF_014323725.1        Actinokineospora xionganensis             1
#
#                     PG_binding_2  PG_binding_3  ...  LysM  Choline_bind_1  \
# assembly_accession                              ...
# GCF_000564855.1                0             0  ...     1               0
# GCF_001940455.1                0             0  ...     1               0
# GCF_002934265.1                1             0  ...     1               0
# GCF_004362515.1                1             0  ...     1               0
# GCF_014323725.1                1             0  ...     1               0
#
#                     Choline_bind_2  Choline_bind_3  CW_binding_2  CW_7  \
# assembly_accession
# GCF_000564855.1                  0               0             0     0
# GCF_001940455.1                  0               0             0     0
# GCF_002934265.1                  0               0             0     0
# GCF_004362515.1                  0               0             0     0
# GCF_014323725.1                  0               0             0     0
#
#                     PSA_CBD  ZoocinA_TRD  GW  OapA
# assembly_accession
# GCF_000564855.1           0            0   0     0
# GCF_001940455.1           0            0   0     0
# GCF_002934265.1           0            0   0     0
# GCF_004362515.1           0            0   0     0
# GCF_014323725.1           0            0   0     0
#
# [5 rows x 31 columns]

# %%
agg_dict = {'assembly_accession': 'nunique'}
for cwb_col in cwb_domains:
    agg_dict[cwb_col] = 'sum'

cwb_genus_summary = cwb_df.reset_index()[
    ['gtdb_phylum', 'gtdb_genus', 'assembly_accession'] + cwb_domains
].groupby(
    ['gtdb_phylum', 'gtdb_genus']
).agg(agg_dict).rename(
    columns={'assembly_accession': 'n_species'}
)

cwb_genus_summary
# Out:
#                                    n_species  PG_binding_1  PG_binding_2  \
# gtdb_phylum    gtdb_genus
# Actinomycetota Actinokineospora           10            10             6
#                Actinoplanes               10            10             6
#                Actinosynnema              10            10             9
#                Aeromicrobium              10             7             0
#                Agrococcus                 10             6             0
# ...                                      ...           ...           ...
# Bacillota_A    Faecalibacterium           10            10             0
#                Mobilitalea                10            10             2
#                Peptoniphilus_A            10             0             0
#                Peptostreptococcus         10             0             0
# Bacillota_F    Halanaerobium              10            10             0
#
#                                    PG_binding_3  AMIN  SPOR  SH3_1  SH3_2  \
# gtdb_phylum    gtdb_genus
# Actinomycetota Actinokineospora               0     0     1      0      0
#                Actinoplanes                   4     0     0      0      0
#                Actinosynnema                  0     0     1      0      0
#                Aeromicrobium                  0     0     0      0      0
#                Agrococcus                     1     0     0      0      0
# ...                                         ...   ...   ...    ...    ...
# Bacillota_A    Faecalibacterium               0     0     1      0      0
#                Mobilitalea                    0     0     7      0      0
#                Peptoniphilus_A                0     0     0      0      0
#                Peptostreptococcus             0     0     3      1      0
# Bacillota_F    Halanaerobium                  1    10    10      0      0
#
#                                    SH3_3  SH3_4  ...  LysM  Choline_bind_1  \
# gtdb_phylum    gtdb_genus                        ...
# Actinomycetota Actinokineospora        0      0  ...    10               0
#                Actinoplanes            1      0  ...    10               0
#                Actinosynnema           3      0  ...    10               0
#                Aeromicrobium           7      0  ...    10               0
#                Agrococcus              0      0  ...     9               0
# ...                                  ...    ...  ...   ...             ...
# Bacillota_A    Faecalibacterium        3      2  ...    10               0
#                Mobilitalea            10      7  ...    10               4
#                Peptoniphilus_A         6      0  ...    10               0
#                Peptostreptococcus     10     10  ...     3              10
# Bacillota_F    Halanaerobium           0      0  ...    10               0
#
#                                    Choline_bind_2  Choline_bind_3  \
# gtdb_phylum    gtdb_genus
# Actinomycetota Actinokineospora                 0               0
#                Actinoplanes                     0               0
#                Actinosynnema                    0               0
#                Aeromicrobium                    0               0
#                Agrococcus                       0               0
# ...                                           ...             ...
# Bacillota_A    Faecalibacterium                 0               2
#                Mobilitalea                      1               4
#                Peptoniphilus_A                  0               0
#                Peptostreptococcus               1              10
# Bacillota_F    Halanaerobium                    0               0
#
#                                    CW_binding_2  CW_7  PSA_CBD  ZoocinA_TRD  \
# gtdb_phylum    gtdb_genus
# Actinomycetota Actinokineospora               1     0        0            0
#                Actinoplanes                   0     0        0            0
#                Actinosynnema                  0     0        0            0
#                Aeromicrobium                  0     0        0            0
#                Agrococcus                     8     1        0            0
# ...                                         ...   ...      ...          ...
# Bacillota_A    Faecalibacterium               0     0        0            0
#                Mobilitalea                    1     0        0            0
#                Peptoniphilus_A                1     3        0            0
#                Peptostreptococcus            10     0        0            0
# Bacillota_F    Halanaerobium                  0     0        0            0
#
#                                    GW  OapA
# gtdb_phylum    gtdb_genus
# Actinomycetota Actinokineospora     0     0
#                Actinoplanes         0     0
#                Actinosynnema        0     0
#                Aeromicrobium        0     0
#                Agrococcus           0     0
# ...                                ..   ...
# Bacillota_A    Faecalibacterium     0     0
#                Mobilitalea          2     0
#                Peptoniphilus_A      0     0
#                Peptostreptococcus   0     0
# Bacillota_F    Halanaerobium        0     0
#
# [106 rows x 25 columns]

# %%
cwb_df.to_csv(data_folder / 'differential_presence' / 'cwb_presence_assembly.csv')
cwb_genus_summary.to_csv(data_folder / 'differential_presence' / 'cwb_presence_genus.csv')

# %%
cwb_df[cwb_df['gtdb_genus'] == 'Streptococcus'][taxonomy_columns + ['LysM', 'PG_binding_1']]
# Out:
#                       domain gtdb_phylum gtdb_class       gtdb_order  \
# assembly_accession
# GCA_002831545.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCA_900637675.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000186445.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000294495.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000785515.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_001457635.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_002055535.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_006739205.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_010120595.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_902702775.1     Bacteria   Bacillota    Bacilli  Lactobacillales
#
#                          gtdb_family     gtdb_genus  \
# assembly_accession
# GCA_002831545.1     Streptococcaceae  Streptococcus
# GCA_900637675.1     Streptococcaceae  Streptococcus
# GCF_000186445.1     Streptococcaceae  Streptococcus
# GCF_000294495.1     Streptococcaceae  Streptococcus
# GCF_000785515.1     Streptococcaceae  Streptococcus
# GCF_001457635.1     Streptococcaceae  Streptococcus
# GCF_002055535.1     Streptococcaceae  Streptococcus
# GCF_006739205.1     Streptococcaceae  Streptococcus
# GCF_010120595.1     Streptococcaceae  Streptococcus
# GCF_902702775.1     Streptococcaceae  Streptococcus
#
#                                   gtdb_species  LysM  PG_binding_1
# assembly_accession
# GCA_002831545.1           Streptococcus suis_P     1             0
# GCA_900637675.1             Streptococcus equi     0             0
# GCF_000186445.1       Streptococcus agalactiae     1             0
# GCF_000294495.1             Streptococcus suis     1             0
# GCF_000785515.1       Streptococcus salivarius     1             0
# GCF_001457635.1       Streptococcus pneumoniae     1             0
# GCF_002055535.1         Streptococcus pyogenes     1             0
# GCF_006739205.1           Streptococcus mutans     1             0
# GCF_010120595.1     Streptococcus thermophilus     1             0
# GCF_902702775.1           Streptococcus suis_W     1             0

# %%
gtdb_metadata.loc['GCA_900637675.1'][['gtdb_species', 'ncbi_assembly_level', 'checkm_completeness']]
# Out:
# gtdb_species           Streptococcus equi
# ncbi_assembly_level       Complete Genome
# checkm_completeness                 98.06
# Name: GCA_900637675.1, dtype: object

# %%
cwb_df[cwb_df['gtdb_genus'] == 'Lactobacillus'][taxonomy_columns + ['LysM', 'PG_binding_1']]
# Out:
#                       domain gtdb_phylum gtdb_class       gtdb_order  \
# assembly_accession
# GCF_000014425.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000159355.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000160855.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_000160875.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_001433875.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_001436455.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_001591845.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_002706375.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_003584685.1     Bacteria   Bacillota    Bacilli  Lactobacillales
# GCF_018987235.1     Bacteria   Bacillota    Bacilli  Lactobacillales
#
#                          gtdb_family     gtdb_genus  \
# assembly_accession
# GCF_000014425.1     Lactobacillaceae  Lactobacillus
# GCF_000159355.1     Lactobacillaceae  Lactobacillus
# GCF_000160855.1     Lactobacillaceae  Lactobacillus
# GCF_000160875.1     Lactobacillaceae  Lactobacillus
# GCF_001433875.1     Lactobacillaceae  Lactobacillus
# GCF_001436455.1     Lactobacillaceae  Lactobacillus
# GCF_001591845.1     Lactobacillaceae  Lactobacillus
# GCF_002706375.1     Lactobacillaceae  Lactobacillus
# GCF_003584685.1     Lactobacillaceae  Lactobacillus
# GCF_018987235.1     Lactobacillaceae  Lactobacillus
#
#                                  gtdb_species  LysM  PG_binding_1
# assembly_accession
# GCF_000014425.1         Lactobacillus gasseri     1             1
# GCF_000159355.1       Lactobacillus johnsonii     1             1
# GCF_000160855.1      Lactobacillus helveticus     1             0
# GCF_000160875.1           Lactobacillus iners     0             1
# GCF_001433875.1     Lactobacillus delbrueckii     1             0
# GCF_001436455.1        Lactobacillus jensenii     1             0
# GCF_001591845.1     Lactobacillus acidophilus     1             0
# GCF_002706375.1      Lactobacillus amylovorus     1             0
# GCF_003584685.1     Lactobacillus paragasseri     1             1
# GCF_018987235.1       Lactobacillus crispatus     1             1
