# %% [markdown]
# # PGB1 logistic regression
#
# The aim is to build a simple logistic regression model that predicts the probaility of presence or absence of the PG_binding_1 domain in a genome given the distribution of presence or absence of all other Pfam & TIGR domains. Phylogeny is also added (taxonomic rank: order) to manage confounding variables.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

cwd = os.getcwd()
if cwd.endswith('notebook'):
    os.chdir('..')
    cwd = os.getcwd()

# %%
sns.set_theme(palette='colorblind', font_scale=1.3)
palette = sns.color_palette().as_hex()

data_folder = Path('./data/')
assert data_folder.is_dir()

db_proka = Path('../db_proka/')
assert db_proka.is_dir()

# %% [markdown]
# ## Load dataset

# %%
target_domain = 'PG_binding_1'

# %% [markdown]
# ### Pfam

# %%
pfam_df = pd.read_csv(data_folder / 'pfam_bacteria.csv', index_col='assembly_accession')
assert target_domain in set(pfam_df.columns)

print(f'Number of genomes: {len(pfam_df):,}')
print(f'Number of domains: {len(pfam_df.columns):,}')
# Out:
# Number of genomes: 32,507
# Number of domains: 3,981

# %%
p = 100 * len(pfam_df[pfam_df[target_domain] == 1]) / len(pfam_df)

print(f'{target_domain} is present in {p:.0f}% of all genomes.')
# Out:
# PG_binding_1 is present in 64% of all genomes.

# %% [markdown]
# ### TIGR

# %%
TIGR_df = pd.read_csv(data_folder / 'TIGR_bacteria.csv', index_col='assembly_accession')

# %% [markdown]
# ### Phylogeny

# %%
phylogeny_df = pd.read_csv(data_folder / 'taxonomy_order_bacteria.csv', index_col='assembly_accession')

# %% [markdown]
# ### Merge datasets

# %%
data_df = pd.merge(
    pfam_df,
    TIGR_df,
    left_index=True,
    right_index=True,
    how='inner',
)
data_df = pd.merge(
    data_df,
    phylogeny_df,
    left_index=True,
    right_index=True,
    how='inner',
)

# %%
print(f'Number of genomes: {len(data_df):,}')
print(f'Number of columns: {len(data_df.columns):,}')
# Out:
# Number of genomes: 32,507
# Number of columns: 6,704

# %% [markdown]
# ## PGB1 exploration

# %%
gtdb_metadata = pd.read_csv(db_proka / 'gtdb_metadata.csv', index_col='ncbi_accession')
gtdb_metadata['domain'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[0].replace('d__', ''))
gtdb_metadata['gtdb_phylum'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[1].replace('p__', ''))
gtdb_metadata['gtdb_class'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[2].replace('c__', ''))
gtdb_metadata['gtdb_order'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[3].replace('o__', ''))
gtdb_metadata['gtdb_family'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[4].replace('f__', ''))
gtdb_metadata['gtdb_genus'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[5].replace('g__', ''))
gtdb_metadata['gtdb_species'] = gtdb_metadata['gtdb_taxonomy'].apply(lambda t: t.split(';')[6].replace('s__', ''))

bacterial_genomes = gtdb_metadata[gtdb_metadata['domain'] == 'Bacteria']

# %%
pgb1_metadata = pd.merge(
    pfam_df[[target_domain]],
    bacterial_genomes[['gtdb_phylum', 'gtdb_class', 'gtdb_order', 'gtdb_family', 'gtdb_genus', 'gtdb_species']],
    left_index=True,
    right_index=True,
)
pgb1_metadata.head()
# Out:
#                  PG_binding_1     gtdb_phylum           gtdb_class  \
# GCA_000007325.1             1  Fusobacteriota        Fusobacteriia
# GCA_000008885.1             0  Pseudomonadota  Gammaproteobacteria
# GCA_000009845.1             0       Bacillota              Bacilli
# GCA_000010565.1             1     Bacillota_B     Desulfotomaculia
# GCA_000011445.1             0       Bacillota              Bacilli
#
#                          gtdb_order         gtdb_family      gtdb_genus  \
# GCA_000007325.1     Fusobacteriales    Fusobacteriaceae   Fusobacterium
# GCA_000008885.1    Enterobacterales  Enterobacteriaceae  Wigglesworthia
# GCA_000009845.1   Acholeplasmatales  Acholeplasmataceae     Phytoplasma
# GCA_000010565.1  Desulfotomaculales    Pelotomaculaceae   Pelotomaculum
# GCA_000011445.1     Mycoplasmatales    Mycoplasmataceae      Mycoplasma
#
#                                     gtdb_species
# GCA_000007325.1          Fusobacterium nucleatum
# GCA_000008885.1     Wigglesworthia glossinidia_A
# GCA_000009845.1          Phytoplasma sp000009845
# GCA_000010565.1  Pelotomaculum thermopropionicum
# GCA_000011445.1              Mycoplasma mycoides

# %%
taxonomy_to_subset = {}
for taxonomy in ['gtdb_phylum', 'gtdb_class', 'gtdb_order', 'gtdb_family', 'gtdb_genus']:
    g = pgb1_metadata[[taxonomy, target_domain]].groupby(taxonomy).agg(['sum', 'count'])

    subset_to_consider = sorted(set(g[
        #(g[(target_domain, 'sum')] > 0) &
        (g[(target_domain, 'count')] > 1)
    ].index))

    taxonomy_to_subset[taxonomy] = subset_to_consider

    p = 100 * len(subset_to_consider) / len(g.index)
    print(f'{taxonomy}: {len(subset_to_consider):,} out of {len(g.index):,} ({p:.0f} %)')
# Out:
# gtdb_phylum: 126 out of 155 (81 %)
# gtdb_class: 300 out of 385 (78 %)
# gtdb_order: 840 out of 1,172 (72 %)
# gtdb_family: 1,850 out of 2,882 (64 %)
# gtdb_genus: 5,860 out of 12,553 (47 %)

# %%
pgb1_subset = pgb1_metadata[
    pgb1_metadata['gtdb_phylum'].isin(taxonomy_to_subset['gtdb_phylum']) &
    pgb1_metadata['gtdb_class'].isin(taxonomy_to_subset['gtdb_class']) &
    pgb1_metadata['gtdb_order'].isin(taxonomy_to_subset['gtdb_order']) &
    pgb1_metadata['gtdb_family'].isin(taxonomy_to_subset['gtdb_family']) &
    pgb1_metadata['gtdb_genus'].isin(taxonomy_to_subset['gtdb_genus'])
]

p = 100 * len(pgb1_subset) / len(pgb1_metadata)
print(f'Relevant genomes: {len(pgb1_subset):,} out of {len(pgb1_metadata):,} ({p:.0f} %)')
# Out:
# Relevant genomes: 25,814 out of 32,507 (79 %)

# %%
# data_df = data_df.loc[pgb1_subset.index]

# %%
print(f'Number of genomes: {len(data_df):,}')
print(f'Number of columns: {len(data_df.columns):,}')
# Out:
# Number of genomes: 32,507
# Number of columns: 6,704

# %%
n_genomes_with_domain = data_df[target_domain].sum()
p = 100 * n_genomes_with_domain / len(data_df)
print(f'Number of genomes with {target_domain}: {n_genomes_with_domain:,} ({p:.0f} %)')
# Out:
# Number of genomes with PG_binding_1: 20,955 (64 %)

# %% [markdown]
# ## Prepare variables

# %%
response = data_df[target_domain]
predictors = data_df.loc[:, data_df.columns != target_domain]

# Add constant term for intercept
predictors = sm.add_constant(predictors)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(predictors, response, test_size=0.1, random_state=123)

# Calculate class weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.array([0, 1]), y=y_train)
weights = np.array([class_weights[0] if x == 0 else class_weights[1] for x in y_train])
print(class_weights)
# Out:
# [1.4014179  0.77734084]

# %% [markdown]
# ## Train logistic regression

# %%
reg_param = 1e-3

# Fitting the logistic regression model
model = sm.GLM(
    y_train, 
    X_train, 
    family=sm.families.Binomial(), 
    freq_weights=weights,
).fit_regularized(
    maxiter=100, 
    alpha=reg_param,
    L1_wt=0.5,
)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/statsmodels/genmod/generalized_linear_model.py:1464: UserWarning: Elastic net fitting did not converge
#   warnings.warn("Elastic net fitting did not converge")

# %% [markdown]
# ## Evaluate model

# %%
# Predict on the validation set
y_pred = model.predict(X_val)
y_pred_binary = [1 if x >= 0.5 else 0 for x in y_pred]

# Calculate validation metrics
accuracy = accuracy_score(y_val, y_pred_binary)
conf_matrix = confusion_matrix(y_val, y_pred_binary)
class_report = classification_report(y_val, y_pred_binary)

print("\nValidation set performance:")
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Validation set performance:
# Accuracy: 0.8741925561365733
# Confusion Matrix:
# [[ 993  121]
#  [ 288 1849]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83      1114
#            1       0.94      0.87      0.90      2137
#
#     accuracy                           0.87      3251
#    macro avg       0.86      0.88      0.86      3251
# weighted avg       0.88      0.87      0.88      3251

# %% [markdown]
# ## Identify top domains

# %%
# Extract p-values and coefficients of the coefficients from the training model
p_values = model.pvalues
coefficients = model.params

# Filter significant p-values
significant_vars = p_values[p_values < 1e-2].sort_values()

# Removing the intercept from the significant variables
try:
    significant_vars = significant_vars.drop('const')
except:
    pass

# Extracting the values of the significant parameters
significant_coefficients = coefficients[significant_vars.index]
sorted_significant_coeff = sorted(significant_coefficients.items(), reverse=True, key=lambda t: t[1])

# Display the ranked significant regressors and their coefficients
print("\nRanked significant regressors from the training set and their coefficients:")
for i, (var, coef) in enumerate(sorted_significant_coeff):
    print(f"{var}: {coef:.3f}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[175], line 2
#       1 # Extract p-values and coefficients of the coefficients from the training model
# ----> 2 p_values = model.pvalues
#       3 coefficients = model.params
#       5 # Filter significant p-values
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cwb/lib/python3.11/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'RegularizedResults' object has no attribute 'pvalues'

# %%
coefficients = model.params
sorted_coeff = sorted(coefficients.items(), reverse=True, key=lambda t: t[1])
for i, (var, coef) in enumerate(sorted_coeff):
    if coef > 0 or coef < 0:
        print(f"{var}: {coef:.3f}")
# Out:
# Scaffold: 1.906
# PG_binding_2: 1.567
# TIGR02283: 1.151
# SpoIIIAC: 0.557
# Spore_III_AB: 0.541
# TIGR01925: 0.424
# TIGR01424: 0.424
# Com_YlbF: 0.406
# TIGR02848: 0.343
# Peptidase_M15_2: 0.335
# TIGR00247: 0.335
# Peptidase_S11: 0.327
# TIGR01134: 0.289
# SpoIIE_N: 0.276
# YkuD: 0.273
# TIGR01646: 0.269
# TIGR00690: 0.267
# DUF1540: 0.266
# Peptidase_S41: 0.265
# RimP_N: 0.264
# Peptidase_M14: 0.249
# HTH_40: 0.242
# TIGR01740: 0.239
# TIGR00225: 0.235
# TIGR01449: 0.229
# ExoD: 0.228
# TIGR00858: 0.223
# DUF378: 0.220
# FxsA: 0.218
# ATP-gua_Ptrans: 0.216
# Peptidase_U4: 0.214
# TIGR00117: 0.211
# TIGR03998: 0.210
# 5-FTHF_cyc-lig: 0.209
# DUF4430: 0.206
# HTH_ParB: 0.198
# PGDH_inter: 0.197
# TIGR02483: 0.197
# TIGR00706: 0.196
# LpxI_C: 0.196
# Cupin_7: 0.192
# HATPase_c_2: 0.191
# DUF808: 0.191
# LMWPc: 0.189
# TIGR01459: 0.189
# CorA: 0.189
# SepF: 0.188
# Thioredox_DsbH: 0.188
# UPF0047: 0.187
# GerA: 0.186
# Dodecin: 0.185
# TIGR04018: 0.183
# Toprim_C_rpt: 0.182
# TIGR01887: 0.179
# TIGR03599: 0.179
# o_Erysipelotrichales: 0.178
# CSD2: 0.175
# PEPCK_N: 0.175
# Fn3-like: 0.173
# TIGR00611: 0.172
# FBPase_2: 0.170
# TIGR01710: 0.167
# WS_DGAT_C: 0.165
# TIGR01490: 0.163
# TIGR02079: 0.163
# APP1_cat: 0.163
# PhoH: 0.162
# TIGR00970: 0.160
# DUF480: 0.157
# TPR_16: 0.156
# DUF4131: 0.155
# PPK2: 0.155
# RelA_AH_RIS: 0.155
# bMG6: 0.155
# Peptidase_M48: 0.154
# FmdA_AmdA: 0.153
# Lip_A_acyltrans: 0.151
# DUF3471: 0.150
# DUF3971: 0.149
# CysG_dimeriser: 0.149
# TIGR02098: 0.149
# DUF512: 0.148
# Peptidase_M74: 0.147
# TIGR03300: 0.146
# HRDC: 0.146
# YMF19: 0.145
# NAPRTase_N: 0.144
# TIGR00207: 0.144
# TIGR00135: 0.144
# MGDG_synth: 0.144
# DivIVA: 0.143
# Inhibitor_I9: 0.143
# TIGR03904: 0.142
# BPL_LplA_LipB_2: 0.139
# TIGR02531: 0.138
# DUF937: 0.138
# Amidase_2: 0.138
# TIGR01364: 0.137
# Sulfotransfer_2: 0.137
# Aldose_epim: 0.137
# ATP-synt_DE: 0.136
# FAA_hydrolase_N: 0.136
# DUF2934: 0.136
# MoCoBD_1: 0.136
# TIGR01933: 0.135
# CSD: 0.134
# Phage_base_V: 0.133
# TIGR00656: 0.133
# TIGR02644: 0.133
# MbhD: 0.133
# Fer4_NifH: 0.133
# Dak1_2: 0.132
# TIGR00528: 0.132
# Chlorophyllase2: 0.132
# DUF554: 0.131
# Thia_YuaJ: 0.131
# TIGR01296: 0.131
# TIGR00040: 0.130
# TIGR01001: 0.129
# Peptidase_C14: 0.129
# TIGR01613: 0.128
# WhiA_N: 0.127
# AsmA_2: 0.127
# TIGR02776: 0.126
# AAA_22: 0.126
# OmpA: 0.125
# LptD_N: 0.125
# Glu_cyclase_2: 0.124
# Methyltr_RsmF_N: 0.124
# TIGR02838: 0.124
# Thioredoxin_9: 0.123
# Acyl-CoA_dh_C: 0.123
# TIGR01266: 0.123
# Erythro_esteras: 0.123
# DUF1292: 0.123
# DZR: 0.122
# TPP_enzyme_M_2: 0.122
# MHYT: 0.121
# Fe_hyd_lg_C: 0.121
# DUF4136: 0.120
# VitK2_biosynth: 0.120
# ClpS: 0.119
# DUF2232: 0.119
# Radical_SAM_2: 0.119
# TIGR00576: 0.119
# TIGR01726: 0.118
# FTP: 0.117
# TIGR03458: 0.117
# Fer4_15: 0.117
# Ligase_CoA: 0.116
# NYN: 0.116
# PGPGW: 0.116
# LpxI_N: 0.115
# TIGR01982: 0.115
# Acetyltransf_5: 0.115
# MraY_sig1: 0.115
# BPL_C: 0.113
# SbcD_C: 0.113
# DUF4870: 0.112
# SurA_N: 0.112
# Lipocalin_2: 0.112
# TIGR02967: 0.112
# Histone_HNS: 0.111
# o_Christensenellales: 0.111
# TIGR01317: 0.111
# TIGR01389: 0.111
# TIGR01340: 0.111
# TIGR00513: 0.110
# YdjC: 0.110
# UPF0014: 0.110
# TIGR01973: 0.110
# TIGR03605: 0.110
# DUF924: 0.109
# TPR_4: 0.109
# Rce1-like: 0.109
# CDO_I: 0.108
# RAMPs: 0.108
# NYN_YacP: 0.107
# Actin: 0.107
# TIGR00525: 0.107
# TIGR03696: 0.107
# CpsB_CapC: 0.106
# CHAP: 0.106
# PFK: 0.105
# RuBisCO_large: 0.105
# HAMP_2: 0.104
# CbiX: 0.104
# TilS: 0.104
# TIGR02429: 0.103
# 5TM-5TMR_LYT: 0.103
# NUDIX_4: 0.102
# TIGR00084: 0.102
# DUF4162: 0.102
# sCache_like: 0.101
# TIGR00274: 0.101
# Asp_Arg_Hydrox: 0.101
# Peptidase_S8: 0.101
# TIGR01784: 0.101
# MMPL: 0.101
# TIGR01260: 0.101
# CAP: 0.100
# Creatinase_N: 0.099
# PrpF: 0.098
# DUF2157: 0.098
# SUI1: 0.098
# Peptidase_M15_3: 0.097
# Cytochrom_CIII: 0.097
# DUF2064: 0.097
# TIGR00374: 0.096
# Eco57I: 0.096
# DBI_PRT: 0.096
# TIGR00219: 0.096
# DUF1638: 0.096
# PrmC_N: 0.095
# Phage_holin_3_6: 0.095
# TIGR01172: 0.095
# WbqC: 0.094
# Zn_protease: 0.093
# TIGR00521: 0.093
# TIGR03828: 0.093
# TIGR03296: 0.093
# TIGR03542: 0.093
# DUF370: 0.093
# PilN: 0.093
# TetR_C_7: 0.093
# DUF418: 0.093
# Na_sulph_symp: 0.093
# TIGR03426: 0.092
# Coat_F: 0.092
# Peptidase_M4: 0.092
# Sugar-bind: 0.092
# AbrB: 0.092
# DUF3656: 0.091
# Peptidase_S66C: 0.091
# TIGR01016: 0.091
# DAPDH_C: 0.091
# TIGR00826: 0.089
# Pro_racemase: 0.089
# TIGR00705: 0.089
# TIGR02241: 0.088
# FG-GAP: 0.088
# TIGR02799: 0.088
# GHL10: 0.088
# SBF_like: 0.088
# QueT: 0.088
# Mt_ATP-synt_B: 0.087
# TIGR01430: 0.087
# TIGR03558: 0.086
# PriA_C: 0.086
# RIO1: 0.086
# Melibiase_C: 0.086
# Gly-zipper_Omp: 0.086
# bPH_1: 0.085
# TIGR02154: 0.085
# LNT_N: 0.085
# DUF520: 0.085
# SlyX: 0.085
# NiFe_hyd_SSU_C: 0.084
# FtsJ: 0.084
# ANF_receptor: 0.083
# DUF2087: 0.083
# NDK: 0.083
# TIGR01362: 0.082
# Cyanophycin_syn: 0.082
# DUF4142: 0.082
# MaoC_dehydrat_N: 0.082
# TIGR01221: 0.082
# TamB: 0.081
# TIGR01222: 0.081
# TIGR02823: 0.081
# Glyco_hydro_57: 0.081
# PEPCK_ATP: 0.081
# TIGR00556: 0.081
# ImpA_N: 0.081
# TIGR00791: 0.080
# MauE: 0.080
# OpuAC: 0.080
# GYF_2: 0.080
# AidB_N: 0.080
# TIGR00091: 0.080
# GDPD_2: 0.080
# Pur_DNA_glyco: 0.079
# TIGR00443: 0.079
# DUF5011: 0.079
# TIGR01451: 0.079
# CwfJ_C_1: 0.078
# DRTGG: 0.078
# Phage_int_SAM_3: 0.078
# SLC35F: 0.078
# CobA_CobO_BtuR: 0.077
# UDPGT: 0.077
# TIGR01139: 0.077
# CinA_KH: 0.077
# cobW: 0.076
# FtsQ_DivIB_C: 0.076
# DNA_photolyase: 0.076
# TIGR00795: 0.076
# zf-trcl: 0.075
# KAP_NTPase: 0.075
# Abhydrolase_3: 0.075
# TIGR00759: 0.075
# HigB_toxin: 0.075
# DUF3298: 0.074
# LCAT: 0.074
# HTH_AsnC-type: 0.074
# Ser_hydrolase: 0.073
# Aconitase_2_N: 0.073
# Acetyltransf_CG: 0.073
# FAD_binding_6: 0.073
# TSP_3: 0.073
# 2-oxogl_dehyd_N: 0.072
# TIGR03423: 0.072
# ROK: 0.071
# Glyco_hydro_25: 0.071
# TIGR00191: 0.071
# TIGR01341: 0.071
# ACT_6: 0.071
# LTXXQ: 0.071
# 3-HAO: 0.070
# DUF421: 0.070
# AIG1: 0.070
# FIST_C: 0.070
# DNA_pol3_gamma3: 0.070
# BE_C: 0.070
# DUF2200: 0.070
# TIGR02176: 0.069
# DAO_C: 0.069
# Glutaredoxin: 0.069
# 4PPT_N: 0.069
# DUF423: 0.069
# MucB_RseB: 0.069
# FlpD: 0.069
# Glucosaminidase: 0.068
# Terminase_6C: 0.068
# NfeD: 0.067
# Trm112p: 0.067
# Pentapeptide_4: 0.067
# DNApol3-delta_C: 0.067
# TIGR03367: 0.067
# PDDEXK_2: 0.067
# Peptidase_S9_N: 0.067
# TIGR00178: 0.067
# YbjN: 0.066
# Macro: 0.066
# DUF819: 0.065
# TIGR02150: 0.065
# SMC_hinge: 0.064
# 2OG-FeII_Oxy_2: 0.064
# Peptidase_M15_4: 0.064
# Collagen: 0.064
# TIGR00462: 0.064
# RVT_1: 0.064
# FHA: 0.063
# DUF3987: 0.062
# Phosphorylase: 0.062
# FrhB_FdhB_C: 0.062
# TIGR00007: 0.062
# TIGR00676: 0.061
# TrmB: 0.061
# TIGR01968: 0.061
# Glyco_hydro_36N: 0.061
# Transp_cyt_pur: 0.061
# TIGR00245: 0.061
# DUF2188: 0.060
# Ank: 0.060
# DUF1003: 0.060
# TIGR00095: 0.060
# DUF3362: 0.060
# TIGR01342: 0.060
# LuxS: 0.060
# AsmA: 0.060
# Flavodoxin_2: 0.059
# MmeI_TRD: 0.059
# Met_gamma_lyase: 0.059
# FtsL: 0.059
# zf-FPG_IleRS: 0.059
# TIGR00654: 0.059
# FliM: 0.059
# TIGR03302: 0.058
# UPF0016: 0.058
# Ribonuclease: 0.058
# TIGR00639: 0.058
# HD_assoc: 0.058
# Choline_kinase: 0.057
# TPR_5: 0.057
# NHL: 0.057
# TIGR01133: 0.057
# TIGR00278: 0.056
# zf-ISL3: 0.056
# ATP-synt_I: 0.056
# DUF4157: 0.056
# TIGR00738: 0.056
# DUF2231: 0.056
# Abhydrolase_11: 0.056
# DUF11: 0.055
# PAAR_motif: 0.055
# DUF4065: 0.055
# TIGR00554: 0.055
# TIGR00367: 0.055
# BBP2: 0.055
# DUF4384: 0.055
# CxxCxxCC: 0.054
# Y2_Tnp: 0.054
# Glyco_tranf_2_4: 0.054
# Ribosomal_S30AE: 0.054
# Yip1: 0.054
# H2O2_YaaD: 0.054
# DUF4126: 0.054
# iPGM_N: 0.054
# DUF2065: 0.053
# Catalase_C: 0.053
# PCC_BT: 0.052
# Ppx-GppA: 0.052
# Asparaginase_2: 0.052
# TIGR00409: 0.052
# TrbI: 0.052
# TIGR01019: 0.052
# TetR_C_6: 0.052
# Terminase_5: 0.052
# HTH_33: 0.051
# Cation_ATPase: 0.051
# ThiF: 0.051
# Mpo1-like: 0.051
# DUF6537: 0.050
# DUF150_C: 0.050
# TIGR00368: 0.050
# HTH_Tnp_ISL3: 0.050
# KH_4: 0.050
# TIGR01179: 0.049
# DUF4340: 0.049
# TIGR00915: 0.049
# Beta-lactamase2: 0.049
# Band_7_1: 0.049
# Acyl_transf_3: 0.049
# PAS_10: 0.049
# EutQ: 0.049
# PepSY_TM: 0.049
# CofH_C: 0.048
# Phytase-like: 0.048
# Fructosamin_kin: 0.048
# PemK_toxin: 0.048
# LAB_N: 0.048
# TRAM: 0.048
# EutB: 0.048
# Gly-zipper_YMGG: 0.048
# TIGR00546: 0.048
# TIGR02140: 0.047
# Na_Pi_cotrans: 0.047
# PMT: 0.047
# Chromate_transp: 0.047
# HupE_UreJ_2: 0.047
# Aldolase: 0.047
# Methyltransf_24: 0.047
# DUF6597: 0.046
# TIGR00479: 0.046
# TIGR03561: 0.046
# Spore_permease: 0.045
# DAGK_prokar: 0.045
# Xan_ur_permease: 0.045
# TIGR00619: 0.045
# Glycoamylase: 0.045
# YgjP-like: 0.045
# Rossmann-like: 0.044
# DUF445: 0.044
# TIGR01065: 0.044
# VWA_3: 0.044
# TIGR00636: 0.044
# OppC_N: 0.044
# TIGR00011: 0.043
# Glyco_hydro_88: 0.043
# PKD_4: 0.043
# Polysacc_synt_3: 0.043
# SUFBD: 0.043
# GCV_T_C: 0.043
# TIGR01883: 0.043
# TIGR00968: 0.043
# PYNP_C: 0.043
# Exosortase_EpsH: 0.042
# BtpA: 0.042
# MTES_1575: 0.042
# He_PIG: 0.042
# B12-binding_2: 0.042
# Proteasome: 0.042
# FloA: 0.042
# TANGO2: 0.042
# PhdYeFM_antitox: 0.041
# TIGR00215: 0.041
# BKACE: 0.041
# Peptidase_A25: 0.041
# PTE: 0.040
# CRS1_YhbY: 0.040
# VWA_2: 0.040
# YdjM: 0.040
# CagE_TrbE_VirB: 0.040
# VIT: 0.040
# HMG-CoA_red: 0.040
# Peptidase_M42: 0.040
# TIGR03804: 0.040
# H-kinase_dim: 0.039
# Fer4_22: 0.039
# AGL_N: 0.039
# AAA_16: 0.039
# TIGR00317: 0.039
# NMN_transporter: 0.038
# Arf: 0.038
# MORN: 0.038
# HTH_16: 0.038
# Kinase-PPPase: 0.038
# DUF294: 0.038
# Ferric_reduct: 0.038
# C_GCAxxG_C_C: 0.037
# Lumazine_bd_2: 0.037
# CCG: 0.037
# YlmH_RBD: 0.037
# Transgly_assoc: 0.037
# TIGR02454: 0.037
# DrsE_2: 0.037
# SASA: 0.037
# THUMP: 0.036
# TIGR00453: 0.036
# HupE_UreJ: 0.036
# DDE_3: 0.036
# TIGR00282: 0.036
# TIGR00515: 0.036
# Thioredoxin_3: 0.035
# HicB_lk_antitox: 0.035
# TIGR01708: 0.035
# PUA_3: 0.035
# SATase_N: 0.035
# PD40: 0.034
# UPF0227: 0.034
# DUF6580: 0.034
# HepT-like: 0.033
# TPR_12: 0.033
# TIGR00747: 0.033
# Methyltransf_14: 0.033
# TIGR00194: 0.033
# WES_acyltransf: 0.033
# ORF6N: 0.032
# TIGR02229: 0.032
# DDE_Tnp_1_6: 0.032
# Lipase_GDSL_3: 0.032
# SE: 0.031
# TIGR00436: 0.030
# ALO: 0.030
# RNase_H: 0.030
# TIGR00963: 0.030
# PRD: 0.030
# TIGR02156: 0.029
# LigT_PEase: 0.029
# DUF1232: 0.029
# TIGR00773: 0.029
# PRC: 0.029
# EF-hand_5: 0.029
# TIGR00979: 0.029
# PRA-PH: 0.029
# TIGR00218: 0.028
# TIGR03168: 0.028
# TIGR03139: 0.028
# Ferritin_2: 0.028
# DUF1801: 0.027
# Dockerin_1: 0.027
# Big_7: 0.027
# FrsA-like: 0.027
# SIMPL: 0.027
# dCache_2: 0.027
# Sigma70_r4_2: 0.027
# PAD_porph: 0.026
# Acetyltransf_9: 0.025
# TIGR02225: 0.025
# TIGR00221: 0.025
# ABC2_membrane_6: 0.025
# TIGR01515: 0.025
# TIGR02707: 0.025
# Cadherin_5: 0.025
# TIGR02379: 0.025
# Glyco_tranf_2_5: 0.024
# GTP-bdg_N: 0.024
# Abhydrolase_4: 0.024
# HTH_36: 0.024
# FUR: 0.024
# TIGR00516: 0.023
# HTH_25: 0.023
# NTP_transf_9: 0.023
# DUF6531: 0.023
# TIGR00067: 0.023
# dTDP_sugar_isom: 0.023
# TIGR00976: 0.023
# DUF805: 0.023
# GPW_gp25: 0.022
# TIGR00419: 0.022
# RtcB: 0.022
# HTH_OrfB_IS605: 0.022
# Sulfotransfer_3: 0.022
# HTH_30: 0.022
# TIGR00020: 0.021
# DnaB_bind: 0.021
# HTH_38: 0.021
# CagX: 0.021
# TIGR01822: 0.021
# TIGR01536: 0.020
# G_glu_transpept: 0.020
# HisKA_3: 0.019
# TIGR02081: 0.019
# CbiQ: 0.019
# LpxD: 0.019
# TIGR00638: 0.019
# DUF2061: 0.018
# OB_aCoA_assoc: 0.018
# Calx-beta: 0.018
# RloB: 0.018
# Glyco_trans_4_4: 0.018
# TIGR01550: 0.018
# DUF2339: 0.018
# TIGR03652: 0.018
# ArAE_1: 0.018
# Ig_mannosidase: 0.017
# GTP-bdg_M: 0.017
# Cellulase: 0.017
# ABC1: 0.017
# TIGR02276: 0.016
# FUSC: 0.016
# YafQ_toxin: 0.016
# Acetyltransf_8: 0.016
# zinc_ribbon_5: 0.016
# TAT_signal: 0.015
# Host_attach: 0.015
# LamB_YcsF: 0.015
# TIGR00080: 0.015
# DUF1778: 0.015
# Sterol-sensing: 0.014
# DUF188: 0.014
# TIGR00842: 0.014
# HTH_34: 0.014
# HTH_17: 0.014
# T2SSC: 0.014
# NLPC_P60: 0.014
# HNH_2: 0.014
# Thioredoxin_5: 0.014
# zf-CDGSH: 0.014
# TIGR00036: 0.014
# GGACT: 0.014
# B12-binding: 0.013
# DivIC: 0.013
# LemA: 0.013
# Acetyltransf_17: 0.012
# FG-GAP_3: 0.012
# TIGR01704: 0.012
# TIGR00018: 0.012
# GNVR: 0.011
# TRI12: 0.011
# SNF2_assoc: 0.011
# TIGR00393: 0.010
# TIGR00390: 0.010
# Melibiase: 0.010
# Fer4_9: 0.010
# DDE_Tnp_1_2: 0.009
# Lactonase: 0.009
# DHquinase_II: 0.008
# HTH_41: 0.008
# TIGR03025: 0.008
# HNH_4: 0.007
# Bac_luciferase: 0.007
# TM2: 0.007
# Glyco_trans_1_2: 0.007
# TIGR01072: 0.007
# DUF202: 0.007
# Glyco_hydro_2_C: 0.007
# TPR_11: 0.007
# Pectate_lyase_3: 0.007
# LAGLIDADG_WhiA: 0.006
# TIGR00417: 0.006
# NOV_C: 0.006
# TIGR02046: 0.005
# CMAS: 0.005
# TM_helix: 0.005
# ABC2_membrane_5: 0.003
# Pro_CA: 0.003
# NACHT: 0.003
# MNHE: 0.002
# DNA_alkylation: 0.002
# TIGR01128: 0.002
# Hist_deacetyl: 0.001
# Epimerase_2: 0.001
# Glyoxalase_2: -0.001
# DUF5915: -0.002
# TIGR03408: -0.002
# Tautomerase: -0.002
# TIGR00176: -0.003
# TarH: -0.004
# Fic_N: -0.005
# TSCPD: -0.005
# TIGR01371: -0.005
# SBP_bac_8: -0.006
# TIGR00643: -0.006
# DUF900: -0.007
# B3_4: -0.007
# DUF4386: -0.007
# 4HBT: -0.009
# TIGR01197: -0.010
# AnmK: -0.010
# ResIII: -0.010
# PIN_3: -0.011
# TIGR00631: -0.011
# G3P_acyltransf: -0.012
# PUCC: -0.012
# DDE_Tnp_1_3: -0.012
# TetR_C_24: -0.013
# TehB: -0.013
# HDOD: -0.013
# Sbt_1: -0.013
# Peptidase_M55: -0.014
# Rieske: -0.014
# PhyH: -0.014
# peroxidase: -0.014
# GTP_EFTU: -0.014
# TIGR03916: -0.014
# Peptidase_C92: -0.015
# TIGR01350: -0.016
# TIGR00685: -0.016
# TIGR00710: -0.017
# TIGR00726: -0.017
# CrtC: -0.017
# DUF4113: -0.017
# TIGR01498: -0.017
# TIGR02246: -0.018
# LptE: -0.018
# Complex1_51K: -0.018
# SepSecS: -0.018
# CutA1: -0.019
# FMN_dh: -0.019
# EpsG: -0.019
# SBP_bac_6: -0.020
# TIGR01312: -0.020
# Glyco_hydro_8: -0.020
# Pyridoxal_deC: -0.020
# tRNA_synt_2f: -0.020
# TIGR00035: -0.020
# GTP_EFTU_D3: -0.021
# TIGR00250: -0.021
# Polyketide_cyc: -0.021
# Y1_Tnp: -0.021
# Ion_trans: -0.021
# TIGR01991: -0.022
# TIGR00457: -0.022
# Gly_radical: -0.022
# TIGR03956: -0.022
# Phos_pyr_kin: -0.022
# OTCace: -0.022
# AAA_19: -0.022
# MPTase-PolyVal: -0.022
# DUF58: -0.023
# DUF3592: -0.023
# TIGR00400: -0.023
# MobC: -0.023
# SWI2_SNF2: -0.023
# Topoisom_I: -0.024
# Protoglobin: -0.024
# TIGR00786: -0.024
# PDH_N: -0.024
# TIGR04380: -0.024
# Pyridox_ox_2: -0.024
# TIGR01104: -0.024
# TIGR02032: -0.024
# Sigma70_r4: -0.024
# Thi4: -0.024
# DUF386: -0.024
# HTH_DeoR: -0.024
# Transglut_core3: -0.025
# Cons_hypoth698: -0.025
# PRiA4_ORF3: -0.025
# Lactamase_B_3: -0.025
# TIGR01444: -0.025
# CsbD: -0.026
# DHDPS: -0.026
# TIGR01178: -0.026
# Glyco_hydro_65C: -0.026
# TIGR00476: -0.026
# Lycopene_cycl: -0.026
# TIGR01843: -0.026
# Dabb: -0.026
# Pirin: -0.027
# DUF3387: -0.027
# TIGR00182: -0.027
# TIGR00266: -0.027
# Alliinase_C: -0.027
# Ldh_2: -0.027
# TIGR00160: -0.027
# RimK: -0.028
# TIGR00675: -0.028
# TIGR01021: -0.028
# DUF3641: -0.028
# YibE_F: -0.028
# Nitroreductase: -0.028
# DUF5655: -0.028
# Sel1: -0.029
# TIGR00524: -0.029
# Endonuclease_NS: -0.029
# ABG_transport: -0.029
# PseudoU_synth_2: -0.030
# HU-HIG: -0.030
# RraA-like: -0.031
# TIGR01195: -0.031
# OsmC: -0.031
# Seryl_tRNA_N: -0.031
# Ni_hydr_CYTB: -0.031
# TIGR01728: -0.031
# PDH_C: -0.032
# YfhO: -0.032
# HPP: -0.033
# zf-TFIIB: -0.033
# TadE: -0.033
# YegS_C: -0.033
# Peptidase_C1_2: -0.033
# HHH_4: -0.033
# CCP_MauG: -0.033
# DUF1329: -0.033
# TIGR02384: -0.034
# ThiI: -0.034
# Desulfoferrodox: -0.034
# Cyclophil_like2: -0.034
# TIGR00129: -0.034
# Acyltransferase: -0.035
# TIGR00437: -0.035
# LRR_8: -0.036
# SIR2: -0.036
# malic: -0.036
# TIGR00456: -0.036
# HEAT_PBS: -0.037
# PEPcase: -0.037
# TOBE_2: -0.037
# NERD: -0.037
# DUF2229: -0.038
# HNH: -0.038
# PTR2: -0.039
# zinc_ribbon_2: -0.039
# DHFR_1: -0.039
# FecR: -0.039
# BFN_dom: -0.039
# DUF1285: -0.040
# AAA_15: -0.040
# BrnA_antitoxin: -0.040
# tRNA_NucTran2_2: -0.041
# TPR_2: -0.041
# TIGR01352: -0.041
# TIGR00427: -0.041
# OCD_Mu_crystall: -0.041
# PS_pyruv_trans: -0.042
# TIGR02281: -0.042
# PqqD: -0.042
# PHP_C: -0.042
# TIGR01383: -0.042
# SNARE_assoc: -0.043
# TIGR01575: -0.043
# TIGR02317: -0.043
# DUF1611: -0.043
# Spore_YtfJ: -0.043
# YjdM: -0.043
# Tex_N: -0.043
# VKOR: -0.044
# RskA: -0.044
# PEGA: -0.044
# DNA_mis_repair: -0.044
# HipA_C: -0.044
# TIGR00127: -0.044
# Fe-ADH: -0.045
# EIID-AGA: -0.045
# TIGR01901: -0.045
# TIGR00099: -0.045
# PaaX_C: -0.045
# TPR_14: -0.045
# TIGR01493: -0.045
# TIGR00056: -0.046
# RelB: -0.046
# TIGR00332: -0.046
# TruD: -0.046
# TPR_7: -0.046
# NadA: -0.047
# PmbA_TldD_C: -0.047
# Peptidase_S10: -0.047
# Peptidase_S9: -0.047
# TIGR01428: -0.047
# Sua5_C: -0.047
# CaMKII_AD: -0.047
# TIGR00514: -0.047
# DNA_pol_B_exo1: -0.048
# TIGR02673: -0.048
# Peptidase_C39_2: -0.048
# VanW: -0.049
# FKBP_C: -0.049
# Glyco_tran_WbsX: -0.049
# Arc: -0.050
# Sigma70_r2: -0.050
# DUF4140: -0.050
# FtsH_ext: -0.050
# CitMHS_2: -0.051
# TIGR01123: -0.051
# OAD_gamma: -0.051
# DHquinase_I: -0.052
# PhoU_div: -0.052
# TIGR01879: -0.052
# HrcA_DNA-bdg: -0.052
# Acetyltransf_6: -0.052
# EutN_CcmL: -0.053
# HlyD_2: -0.053
# FTCD_C: -0.055
# TIGR01344: -0.055
# XFP_C: -0.055
# DUF2721: -0.055
# Oxidored_molyb: -0.056
# PRAI: -0.056
# DUF6088: -0.056
# Glyco_hydro_43: -0.056
# DUF465: -0.056
# TIGR00372: -0.056
# Rad51: -0.056
# Na_Ala_symp: -0.056
# DUF1684: -0.056
# dCMP_cyt_deam_1: -0.056
# Smr: -0.057
# DAC: -0.057
# FRG: -0.057
# DrsE: -0.057
# Hydantoinase_B: -0.057
# Guanylate_cyc: -0.057
# N6_N4_Mtase: -0.058
# Helicase_C: -0.058
# TIGR02817: -0.058
# LolA_like: -0.058
# TgpA_N: -0.059
# Fasciclin: -0.059
# DUF2071: -0.059
# TIGR03824: -0.059
# DUF456: -0.059
# OTCace_N: -0.059
# FCD: -0.059
# DUF934: -0.059
# UPF0060: -0.059
# bact-PGI_C: -0.060
# Virulence_RhuM: -0.060
# NiFeSe_Hases: -0.060
# TIGR00420: -0.060
# Pmp3: -0.060
# DUF411: -0.060
# DDAH_eukar: -0.060
# Ketoacyl-synt_2: -0.060
# PriA_CRR: -0.061
# TIGR00614: -0.061
# Virul_fac_BrkB: -0.061
# FR47: -0.062
# 3HCDH_N: -0.062
# Lactamase_B_6: -0.062
# DUF815: -0.062
# TIGR00551: -0.062
# TIGR02891: -0.062
# PIN_4: -0.063
# TIGR00073: -0.063
# Bac_DnaA: -0.063
# TAL_FSA: -0.063
# DAHP_synth_2: -0.063
# PhoD_N: -0.064
# TIGR01744: -0.064
# TPR_6: -0.064
# TIGR02515: -0.064
# YaeQ: -0.064
# PLDc_2: -0.064
# FliH: -0.064
# Arginase: -0.064
# FleQ: -0.064
# TIGR00444: -0.065
# TIGR00068: -0.065
# Lon_C: -0.066
# TIGR00416: -0.066
# TIGR00382: -0.066
# Glyco_hydro_114: -0.066
# RecQ_Zn_bind: -0.066
# Ribonuc_red_lgN: -0.066
# TIGR00564: -0.067
# TIGR01311: -0.067
# TIGR03409: -0.067
# TspO_MBR: -0.067
# DUF4154: -0.067
# TIGR02210: -0.067
# HicB: -0.068
# TIGR00159: -0.068
# Cauli_VI: -0.068
# TIGR00735: -0.068
# Lipase_GDSL_2: -0.068
# DUF368: -0.069
# AAA_14: -0.069
# EVE: -0.069
# DUF2062: -0.070
# CoA_binding_3: -0.070
# TIGR01737: -0.070
# Rib_5-P_isom_A: -0.070
# HTH_29: -0.071
# GAF: -0.071
# DUF5981: -0.071
# POTRA_2: -0.071
# zf-C4_Topoisom: -0.072
# TIGR02870: -0.072
# TIGR00299: -0.073
# TPR_9: -0.074
# MlaC: -0.074
# TIGR02039: -0.075
# Bac_globin: -0.075
# TIGR00442: -0.075
# TIGR01212: -0.075
# TIGR03356: -0.076
# Cupin_6: -0.076
# o_Sphingomonadales: -0.076
# Hpr_kinase_N: -0.076
# SnoaL_3: -0.076
# TIGR01941: -0.076
# Adenylsucc_synt: -0.076
# DUF1501: -0.077
# FSH1: -0.077
# Fn3_assoc: -0.077
# TIGR00987: -0.078
# dNK: -0.078
# LpoB: -0.078
# YbbR: -0.078
# TIGR00234: -0.078
# CLP_protease: -0.078
# TIGR00460: -0.079
# TIGR01070: -0.079
# OmpW: -0.079
# MutL_C: -0.079
# TIGR01225: -0.079
# HTH_12: -0.080
# Rubredoxin_2: -0.080
# FliD_N: -0.080
# G5: -0.080
# Acid_phosphat_B: -0.081
# TIGR01662: -0.081
# TIGR01462: -0.081
# DUF1328: -0.081
# Thioredoxin_4: -0.082
# AAA_28: -0.082
# TIGR01682: -0.083
# TIGR03936: -0.083
# Glyco_tranf_2_2: -0.083
# TIGR01722: -0.084
# ASL_C: -0.084
# HHH_8: -0.084
# Acatn: -0.085
# TIGR01347: -0.085
# HGSNAT_cat: -0.085
# Dala_Dala_lig_N: -0.085
# TrmO_C: -0.085
# Y_phosphatase: -0.086
# DNA_pol_A_exo1: -0.086
# TIGR02022: -0.086
# TIGR00406: -0.086
# HATPase_c_5: -0.087
# TIGR00720: -0.087
# TruB-C_2: -0.088
# TIGR00741: -0.089
# TIGR00658: -0.089
# CstA: -0.089
# Glyco_hydro_42C: -0.089
# TIGR00763: -0.089
# BATS: -0.090
# DLH: -0.090
# TIGR01414: -0.090
# SnoaL_2: -0.091
# TIGR00711: -0.091
# EutA: -0.091
# Peptidase_M3: -0.091
# RimM: -0.091
# PNK3P: -0.091
# TIGR00875: -0.093
# Bac_DnaA_C: -0.093
# ketoacyl-synt: -0.093
# TIGR03023: -0.094
# zf-CGNR: -0.094
# Lum_binding: -0.095
# LptF_LptG: -0.095
# HATPase_c_4: -0.095
# TIGR01534: -0.097
# TIGR00652: -0.097
# STAS: -0.097
# DUF3458_C: -0.097
# TIGR00054: -0.097
# Peptidase_M28: -0.097
# Sulf_transp: -0.097
# SbmA_BacA: -0.098
# TIGR01579: -0.098
# TIGR01354: -0.098
# tRNA-synt_1c_C: -0.098
# DUF3800: -0.099
# AMP-binding: -0.100
# Dala_Dala_lig_C: -0.100
# HGD-D: -0.100
# Glyco_hydro_38N: -0.100
# TIGR04265: -0.101
# TIGR00231: -0.101
# TK: -0.102
# TIGR01472: -0.102
# YitT_membrane: -0.102
# HWE_HK: -0.102
# Asp_decarbox: -0.102
# TctC: -0.103
# TIGR01910: -0.103
# ACT_7: -0.103
# SprT-like: -0.103
# TIGR00486: -0.104
# TMEM175: -0.104
# TIGR01617: -0.105
# MltA: -0.105
# DUF4015: -0.105
# TIGR00010: -0.105
# Aminotran_1_2: -0.105
# TIGR01882: -0.106
# TIGR00361: -0.107
# ATP-grasp_5: -0.107
# TIGR00965: -0.107
# PQQ_3: -0.107
# TIGR02945: -0.108
# NtrY_N: -0.110
# Mannitol_dh_C: -0.110
# TIGR02669: -0.110
# Rhodanese: -0.111
# zf-ACC: -0.111
# TIGR02666: -0.112
# CopG_antitoxin: -0.112
# YbjQ_1: -0.113
# Acyl-ACP_TE: -0.114
# MCM: -0.114
# CTP_synth_N: -0.114
# DeoC: -0.115
# DUF4115: -0.115
# HA2: -0.115
# DbpA: -0.116
# TIGR03464: -0.116
# TIGR02822: -0.117
# HlyD_D23: -0.118
# PyrI_C: -0.118
# Anticodon_3: -0.119
# Thymidylate_kin: -0.120
# DUF3459: -0.120
# AA_permease_C: -0.120
# Gluconate_2-dh3: -0.120
# DnaA_N: -0.120
# IPT: -0.121
# FAD-oxidase_C: -0.123
# Glyco_hydro_42: -0.123
# DUF2867: -0.123
# FlgM: -0.123
# TIGR01036: -0.124
# Ribosomal_L17: -0.124
# GATase_3: -0.124
# Phe_tRNA-synt_N: -0.125
# TIGR01069: -0.126
# TIGR00131: -0.126
# TIGR00209: -0.126
# TIGR01051: -0.127
# TIGR00383: -0.127
# NAD_kinase: -0.128
# SpoIIM: -0.128
# TIGR00797: -0.128
# AAA_18: -0.128
# AMP_N: -0.128
# Pyrophosphatase: -0.128
# TIGR02170: -0.129
# TIGR00978: -0.129
# TIGR03330: -0.129
# Peptidase_M13: -0.130
# DUF3417: -0.130
# FeS: -0.130
# DUF502: -0.131
# TIGR03263: -0.133
# TIGR02683: -0.133
# TIGR00312: -0.134
# Lactamase_B_2: -0.134
# Glycos_transf_2: -0.134
# TIGR00030: -0.134
# PRK: -0.134
# TIGR03167: -0.135
# DcpS_C: -0.136
# TIGR00755: -0.136
# TIGR00928: -0.137
# MASE1: -0.140
# TIGR00013: -0.141
# Sacchrp_dh_C: -0.141
# Bactofilin: -0.142
# DUF1178: -0.143
# Lipoprotein_8: -0.146
# MutS_II: -0.147
# TIGR00170: -0.149
# His_Phos_1: -0.150
# DNA_pol3_delt_C: -0.150
# FliS: -0.151
# QueH: -0.154
# PadR: -0.155
# DEAD: -0.159
# TIGR01892: -0.160
# PucR: -0.161
# CYTH: -0.163
# FemAB: -0.163
# FolB: -0.167
# CarbopepD_reg_2: -0.167
# Glyco_hydro_20b: -0.168
# GlnE: -0.172
# ATPgrasp_ST: -0.172
# NFACT_N: -0.175
# S4_2: -0.176
# TrkA_C: -0.177
# TIGR02222: -0.181
# TIGR01324: -0.184
# Exonuc_V_gamma: -0.186
# TIGR00197: -0.197
# TIGR00344: -0.197
# Ppnp: -0.198
# TIGR00878: -0.201
# TIGR00997: -0.206
# TIGR01695: -0.209
# TIGR01191: -0.209
# Se-cys_synth_N: -0.213
# Cu_amine_oxidN1: -0.220
# Porin_O_P: -0.227
# TIGR00768: -0.233
# Thioredoxin_7: -0.233
# OmpH: -0.249
# HemX: -0.260
# LysM: -0.261
# CNNM: -0.262
# Phage_integrase: -0.273
# PrmA: -0.304
# Peptidase_S49: -0.322
# TIGR02127: -0.340
# TIGR02729: -0.382

# %%
acc = TIGR_df[TIGR_df['TIGR02729'] == 1].index
gtdb_metadata.loc[acc].reset_index()[['gtdb_phylum', 'gtdb_class', 'gtdb_order', 'assembly_accession']].groupby([
    'gtdb_phylum', 'gtdb_class', 'gtdb_order'
]).count().sort_values('assembly_accession', ascending=False).head(20)
# Out:
#                                                         assembly_accession
# gtdb_phylum     gtdb_class          gtdb_order
# Pseudomonadota  Gammaproteobacteria Burkholderiales                   1695
# Bacillota_A     Clostridia          Lachnospirales                    1257
# Bacteroidota    Bacteroidia         Bacteroidales                     1226
# Bacillota_A     Clostridia          Oscillospirales                   1217
# Bacteroidota    Bacteroidia         Flavobacteriales                  1047
# Pseudomonadota  Alphaproteobacteria Rhizobiales                       1022
# Actinomycetota  Actinomycetia       Actinomycetales                    986
# Pseudomonadota  Alphaproteobacteria Rhodobacterales                    866
#                 Gammaproteobacteria Pseudomonadales                    731
#                                     Enterobacterales_A                 574
# Bacteroidota    Bacteroidia         Chitinophagales                    536
# Bacillota_A     Clostridia          Christensenellales                 507
# Pseudomonadota  Gammaproteobacteria Enterobacterales                   495
# Bacillota       Bacilli             Lactobacillales                    479
#                                     Bacillales                         463
# Actinomycetota  Actinomycetia       Mycobacteriales                    461
# Bacteroidota    Bacteroidia         Cytophagales                       391
# Cyanobacteriota Cyanobacteriia      Cyanobacteriales                   367
# Actinomycetota  Acidimicrobiia      Acidimicrobiales                   353
# Pseudomonadota  Alphaproteobacteria Sphingomonadales                   351
